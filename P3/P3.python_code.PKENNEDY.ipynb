# %% [markdown]
# # Open Street Map
# ## PKENNEDY
# ### First things first, let's import some initial relevant libraries and set our path

# %%
from xml.etree import cElementTree as ET  # Use cElementTree or lxml if too slow
from collections import defaultdict
import pprint
import re
DATA_DIR = '/Users/patrickkennedy/Downloads'
atx_osm = DATA_DIR + '/austin_texas.osm'

# %% [markdown]
# ### For purposes of testing, let's make a smaller file called sample by which we can audit and clean

# %%
#For the submission of a smaller data set (~8mb)

#!/usr/bin/env python
# -*- coding: utf-8 -*-

#NOTE: code provided in instructions

OSM_FILE = atx_osm
SAMPLE_FILE = "sample.osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every 5th top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % 5 == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# ### Great, now let's dig in...

# %%
#Given street names may offer varying standards, let's set some initial definitions...
#we will use both the expected list and mapping dictionary to identify if street names follow the expected conventions

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Cove", "Highway", "North", "East", "West", "South"]

mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Rd." : "Road",
            "Rd" : "Road",
            "Blvd" : "Boulevard",
            "Blvd." : "Boulevard",
            "Ln." : "Lane",
            "Ln" : "Lane",
            "Cv" : "Cove",
            "Cv." : "Cove",
            "Dr" : "Drive",
            "Dr." : "Dr",
            "Ct" : "Court",
            "Ct." : "Court",
            "Ovlk" : "Overlook",
            "Ovlk." : "Overlook",
            "Pkwy" : "Parkway",
            "Pkwy." : "Parkway",
            "Pl" : "Place",
            "Pl." : "Place",
            "Tr": "Trail",
            "Trl": "Trail",
            "Tr.": "Trail",
            "Trl.": "Trail",
            "street" : "Street",
            "cove" : "Cove",
            "lane" : "Lane",
            "court" : "Court",
            "pass" : "Pass",
            "HWY" : "Highway",
            "Hwy" : "Highway",
            "N" : "North",
            "N." : "North",
            "E" : "East",
            "E." : "East",
            "W" : "West",
            "W." : "West",
            "S" : "South",
            "S." : "South",
            "US" : "U.S."
            }

# %%
#Auditing street name data

#use regex to ID the street name
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

#add all unexpected street names to the street_types set
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

#if the attribute key matches 'addr:street', it is a street
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

#open the osm file and iterate using event based parsing
#navigate to the street, and audit, returning the street_types set
def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

#for each street name, check each element and replace each split element
#of the street name with a value in the mapping dictionary if the mapping key matches the split element
def update_name(name, mapping):

    split_name = name.split(" ")
    for index, i in enumerate(split_name):
        if i in mapping:
            split_name[index] = mapping[i]
    name = " ".join(split_name)
    
    return name

#test to see if the functions above work and print out the initial streets with their corrected versions
def test():
    st_types = audit(atx_osm)
    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name

if __name__ == '__main__':
    test()
# Out:
# Merimac => Merimac
# Clara Van => Clara Van
# Capri => Capri
# Chelsea Moor => Chelsea Moor
# Royal Birkdale Ovlk => Royal Birkdale Overlook
# Lions Lair => Lions Lair
# Apache => Apache
# Farm-to-Market Road 812 => Farm-to-Market Road 812
# Bee Cave Road Suite 163 => Bee Cave Road Suite 163
# Adventurer => Adventurer
# Affirmed => Affirmed
# West 35th Street Cutoff => West 35th Street Cutoff
# Ferguson Cutoff => Ferguson Cutoff
# House Wren => House Wren
# N I-35 Suite 298 => North I-35 Suite 298
# Melody => Melody
# East Highway 290 => East Highway 290
# Highway 290 => Highway 290
# W. Highway 290 => West Highway 290
# East Hwy 290 => East Highway 290
# C R 290 => C R 290
# W US Highway 290 => West U.S. Highway 290
# West Highway 290 => West Highway 290
# W Hwy 290 => West Highway 290
# U.S. 290 => U.S. 290
# E Hwy 290 => East Highway 290
# US Highway 290 => U.S. Highway 290
# County Road 290 => County Road 290
# W Highway 290 => West Highway 290
# W HWY 290 => West Highway 290
# US 290 => U.S. 290
# Pony Chase => Pony Chase
# Pecan Chase => Pecan Chase
# Mustang Chase => Mustang Chase
# Glen Rose Chase => Glen Rose Chase
# Shetland Chase => Shetland Chase
# Wild Basin Lodge => Wild Basin Lodge
# Palm Harborway => Palm Harborway
# south church street => south church Street
# East main street => East main Street
# South 1st street => South 1st Street
# White House street => White House Street
# Carlos G Parker Boulevard Northwest => Carlos G Parker Boulevard Northwest
# Raven Caw pass => Raven Caw Pass
# Craigwood Circle => Craigwood Circle
# Canyonbend Circle => Canyonbend Circle
# Cedar Circle => Cedar Circle
# Haddick Circle => Haddick Circle
# Button Bend Circle => Button Bend Circle
# Pecan Circle => Pecan Circle
# Howerington Circle => Howerington Circle
# Buena Vista Circle => Buena Vista Circle
# Rimrock Circle => Rimrock Circle
# Federal Circle => Federal Circle
# Lindenwood Circle => Lindenwood Circle
# Silone Circle => Silone Circle
# Heathercrest Circle => Heathercrest Circle
# Jolena Circle => Jolena Circle
# Brompton Circle => Brompton Circle
# Alameda Trace Circle => Alameda Trace Circle
# Hedder Circle => Hedder Circle
# Mistywood Circle => Mistywood Circle
# Augusta Circle => Augusta Circle
# Little Creek Circle => Little Creek Circle
# Cheyenne Circle => Cheyenne Circle
# Winners Ribbon Circle => Winners Ribbon Circle
# Oakdale Circle => Oakdale Circle
# Big Oak Circle => Big Oak Circle
# Brighton Circle => Brighton Circle
# Cascade Circle => Cascade Circle
# Tanager Circle => Tanager Circle
# Sunset River Circle => Sunset River Circle
# Crosswind Circle => Crosswind Circle
# Beck Circle => Beck Circle
# Hupa Circle => Hupa Circle
# Lamplight Village Circle => Lamplight Village Circle
# Villacliff Circle => Villacliff Circle
# Champions Circle => Champions Circle
# Hill Meadow Circle => Hill Meadow Circle
# Frost Circle => Frost Circle
# Apache Springs Circle => Apache Springs Circle
# Oak Shadows Circle => Oak Shadows Circle
# Ceylon Tea Circle => Ceylon Tea Circle
# Folklore Circle => Folklore Circle
# Balcones Woods Circle => Balcones Woods Circle
# Little Hill Circle => Little Hill Circle
# Fawn Circle => Fawn Circle
# Firestone Circle => Firestone Circle
# Cannes Circle => Cannes Circle
# Palma Circle => Palma Circle
# Hayride Circle => Hayride Circle
# Bissel Circle => Bissel Circle
# Merrybrook Circle => Merrybrook Circle
# Blue Spruce Circle => Blue Spruce Circle
# Whispering Creek Circle => Whispering Creek Circle
# Salem Meadow Circle => Salem Meadow Circle
# Jester Circle => Jester Circle
# Tumbling Circle => Tumbling Circle
# Oak Grove Circle => Oak Grove Circle
# Countryside Circle => Countryside Circle
# Scarlet Circle => Scarlet Circle
# Waxwing Circle => Waxwing Circle
# Sawatch Circle => Sawatch Circle
# Silver Hill Circle => Silver Hill Circle
# Hogan Circle => Hogan Circle
# Dove Springs Circle => Dove Springs Circle
# Talyne Chaise Circle => Talyne Chaise Circle
# Pleasant Meadow Circle => Pleasant Meadow Circle
# Plateau Circle => Plateau Circle
# Towbridge Circle => Towbridge Circle
# Botany Bay Circle => Botany Bay Circle
# Maywood Circle => Maywood Circle
# Dormax Circle => Dormax Circle
# Vance Circle => Vance Circle
# Declaration Circle => Declaration Circle
# Palm Circle => Palm Circle
# Washoe Circle => Washoe Circle
# Rainbow Ridge Circle => Rainbow Ridge Circle
# Timber Wolf Circle => Timber Wolf Circle
# Hurst Creek Circle => Hurst Creek Circle
# Booth Circle => Booth Circle
# Bluestone Circle => Bluestone Circle
# Mourning Dove Circle => Mourning Dove Circle
# Wigwam Circle => Wigwam Circle
# Creekwood Circle => Creekwood Circle
# Flintrock Circle => Flintrock Circle
# Evening Sky Circle => Evening Sky Circle
# Bahia Circle => Bahia Circle
# Crystal Creek Circle => Crystal Creek Circle
# Chippewa Circle => Chippewa Circle
# Maplelawn Circle => Maplelawn Circle
# Raleigh Circle => Raleigh Circle
# Lake Wood Circle => Lake Wood Circle
# Quail Rock Circle => Quail Rock Circle
# Northcrest Circle => Northcrest Circle
# Santa Elena Circle => Santa Elena Circle
# Universe Circle => Universe Circle
# Bluff Park Circle => Bluff Park Circle
# Charm Circle => Charm Circle
# Hamden Circle => Hamden Circle
# Morado Circle => Morado Circle
# Mountain Lake Circle => Mountain Lake Circle
# Bay Circle => Bay Circle
# Maha Circle => Maha Circle
# Glencoe Circle => Glencoe Circle
# Chayton Circle => Chayton Circle
# Valburn Circle => Valburn Circle
# Compass Circle => Compass Circle
# Coats Circle => Coats Circle
# Morningstar Circle => Morningstar Circle
# Stone Ledge Circle => Stone Ledge Circle
# Sunrise Circle => Sunrise Circle
# Fairmont Circle => Fairmont Circle
# Caladium Circle => Caladium Circle
# Single Shot Circle => Single Shot Circle
# Congressional Circle => Congressional Circle
# Courtland Circle => Courtland Circle
# Powell Circle => Powell Circle
# Partridge Circle => Partridge Circle
# Beauregard Circle => Beauregard Circle
# Hull Circle => Hull Circle
# Lewood Circle => Lewood Circle
# Bramblewood Circle => Bramblewood Circle
# Gavilan Circle => Gavilan Circle
# Lostwood Circle => Lostwood Circle
# Mount View Circle => Mount View Circle
# Evadean Circle => Evadean Circle
# Highpoint Circle => Highpoint Circle
# Burnt Circle => Burnt Circle
# Merion Circle => Merion Circle
# Cima Circle => Cima Circle
# Patio Circle => Patio Circle
# Big Trail Circle => Big Trail Circle
# Spring Circle => Spring Circle
# Burris Circle => Burris Circle
# Alpine Circle => Alpine Circle
# Bella Montagna Circle => Bella Montagna Circle
# Dill Circle => Dill Circle
# Hardy Circle => Hardy Circle
# Mountainwood Circle => Mountainwood Circle
# Avebury Circle => Avebury Circle
# Bee Tree Circle => Bee Tree Circle
# Madrone Circle => Madrone Circle
# Guajolote Circle => Guajolote Circle
# Harvest Circle => Harvest Circle
# Tangleridge Circle => Tangleridge Circle
# Tejon Circle => Tejon Circle
# Southgate Circle => Southgate Circle
# High Mountain Circle => High Mountain Circle
# Versante Circle => Versante Circle
# Dondale Circle => Dondale Circle
# Galleria Circle => Galleria Circle
# Hillside Circle => Hillside Circle
# Dakota Circle => Dakota Circle
# Midoak Circle => Midoak Circle
# Wheeler Branch Circle => Wheeler Branch Circle
# Inverrary Circle => Inverrary Circle
# Courtleigh Circle => Courtleigh Circle
# Constantino Circle => Constantino Circle
# Aurora Circle => Aurora Circle
# Stow Circle => Stow Circle
# Tuscola Circle => Tuscola Circle
# Charla Circle => Charla Circle
# Beaconsdale Circle => Beaconsdale Circle
# Cherry Meadow Circle => Cherry Meadow Circle
# Saint Edward's Circle => Saint Edward's Circle
# Elk Park Circle => Elk Park Circle
# South Crest Circle => South Crest Circle
# Split Oak Circle => Split Oak Circle
# Teaberry Circle => Teaberry Circle
# Trailridge Circle => Trailridge Circle
# Constellation Circle => Constellation Circle
# Bitteroot Circle => Bitteroot Circle
# Sage Hollow Circle => Sage Hollow Circle
# Buckingham Circle => Buckingham Circle
# White Magnolia Circle => White Magnolia Circle
# Flinnwood Circle => Flinnwood Circle
# Mount Bonnell Circle => Mount Bonnell Circle
# West Beach Circle => West Beach Circle
# Hillbrook Circle => Hillbrook Circle
# Inwood Circle => Inwood Circle
# Vanderbilt Circle => Vanderbilt Circle
# Rockpoint Circle => Rockpoint Circle
# White Hills Circle => White Hills Circle
# Roundtop Circle => Roundtop Circle
# Homedale Circle => Homedale Circle
# Silver Dale Circle => Silver Dale Circle
# Camelot Circle => Camelot Circle
# Wheel Rim Circle => Wheel Rim Circle
# Mia Tia Circle => Mia Tia Circle
# Stroup Circle => Stroup Circle
# Diversion Circle => Diversion Circle
# Rockpark Circle => Rockpark Circle
# Mountain Ridge Circle => Mountain Ridge Circle
# Walden Circle => Walden Circle
# Edge Park Circle => Edge Park Circle
# Scenic Circle => Scenic Circle
# Ellington Circle => Ellington Circle
# Lampwick Circle => Lampwick Circle
# Oak Haven Circle => Oak Haven Circle
# Fitchburg Circle => Fitchburg Circle
# Overstreet Circle => Overstreet Circle
# Lost Creek Circle => Lost Creek Circle
# Cedarhurst Circle => Cedarhurst Circle
# Sandhurst Circle => Sandhurst Circle
# Paradise Manor Circle => Paradise Manor Circle
# Twin Lake Circle => Twin Lake Circle
# Wildridge Circle => Wildridge Circle
# Flynn Circle => Flynn Circle
# Apple Springs Circle => Apple Springs Circle
# Flintlock Circle => Flintlock Circle
# Winding Oak Circle => Winding Oak Circle
# Central Commerce Circle => Central Commerce Circle
# Merrywing Circle => Merrywing Circle
# Monticello Circle => Monticello Circle
# Quailfield Circle => Quailfield Circle
# Westwood Circle => Westwood Circle
# Whispering Hollow Circle => Whispering Hollow Circle
# York Bridge Circle => York Bridge Circle
# Chevy Circle => Chevy Circle
# Blue Water Circle => Blue Water Circle
# Michele Circle => Michele Circle
# Ewing Circle => Ewing Circle
# Quail Cover Circle => Quail Cover Circle
# Briar Wood Circle => Briar Wood Circle
# Gateshead Circle => Gateshead Circle
# Post Oak Circle => Post Oak Circle
# Lee Sage Circle => Lee Sage Circle
# Westledge Circle => Westledge Circle
# Sweeney Circle => Sweeney Circle
# Three Oaks Circle => Three Oaks Circle
# Hamilton Point Circle => Hamilton Point Circle
# Woodbrook Circle => Woodbrook Circle
# Paloma Circle => Paloma Circle
# Abbate Circle => Abbate Circle
# Soft Wind Circle => Soft Wind Circle
# Knight Circle => Knight Circle
# Ardmore Circle => Ardmore Circle
# Earl Circle => Earl Circle
# Berrylawn Circle => Berrylawn Circle
# Caisson Circle => Caisson Circle
# Taline Circle => Taline Circle
# Dawnridge Circle => Dawnridge Circle
# Palmetto Circle => Palmetto Circle
# Desert Oak Circle => Desert Oak Circle
# Bexton Circle => Bexton Circle
# Penelope Circle => Penelope Circle
# Lakepoint Circle => Lakepoint Circle
# Summer Circle => Summer Circle
# Indio Circle => Indio Circle
# Glenview Circle => Glenview Circle
# Timberwood Circle => Timberwood Circle
# Kollmeyer Circle => Kollmeyer Circle
# Jill Sue Circle => Jill Sue Circle
# Birdlip Circle => Birdlip Circle
# Fox Chase Circle => Fox Chase Circle
# Centimeter Circle => Centimeter Circle
# Manor Circle => Manor Circle
# Aguila Circle => Aguila Circle
# Cliff Circle => Cliff Circle
# Cedarlawn Circle => Cedarlawn Circle
# Valley Hill Circle => Valley Hill Circle
# Geneva Circle => Geneva Circle
# Blinn Circle => Blinn Circle
# Inspiration Circle => Inspiration Circle
# Sea Ash Circle => Sea Ash Circle
# Overlook Circle => Overlook Circle
# Park Circle => Park Circle
# Hillview Circle => Hillview Circle
# Mistyglen Circle => Mistyglen Circle
# Berry Hill Circle => Berry Hill Circle
# Darvone Circle => Darvone Circle
# Spruceleaf Circle => Spruceleaf Circle
# Belo Horizonte Circle => Belo Horizonte Circle
# Stoneham Circle => Stoneham Circle
# Kentshire Circle => Kentshire Circle
# Sparkling Creek Circle => Sparkling Creek Circle
# Pistol Pass Circle => Pistol Pass Circle
# Hood Circle => Hood Circle
# Framingham Circle => Framingham Circle
# Tamarisk Circle => Tamarisk Circle
# Dry Run Circle => Dry Run Circle
# Manana Mountain Circle => Manana Mountain Circle
# Rock Terrace Circle => Rock Terrace Circle
# Manchester Circle => Manchester Circle
# Oak Cliff Circle => Oak Cliff Circle
# Valencia Circle => Valencia Circle
# Galliano Circle => Galliano Circle
# Townesouth Circle => Townesouth Circle
# Cromwell Circle => Cromwell Circle
# Silver Dollar Circle => Silver Dollar Circle
# Paseo de Vaca Circle => Paseo de Vaca Circle
# Donovan Circle => Donovan Circle
# Terra Oak Circle => Terra Oak Circle
# River Crossing Circle => River Crossing Circle
# Howden Circle => Howden Circle
# Leesburg Circle => Leesburg Circle
# Range Oak Circle => Range Oak Circle
# Minda Circle => Minda Circle
# The Circle => The Circle
# Flagstaff Circle => Flagstaff Circle
# Bluffridge Circle => Bluffridge Circle
# Southill Circle => Southill Circle
# Sandy Meadow Circle => Sandy Meadow Circle
# North Ridge Circle => North Ridge Circle
# Crosby Circle => Crosby Circle
# Pond View Circle => Pond View Circle
# Garcreek Circle => Garcreek Circle
# Mecca Circle => Mecca Circle
# Stoutwood Circle => Stoutwood Circle
# Twin Valley Circle => Twin Valley Circle
# Garrison Circle => Garrison Circle
# Fairlake Circle => Fairlake Circle
# Leaf Circle => Leaf Circle
# Chittim Circle => Chittim Circle
# Barton Point Circle => Barton Point Circle
# Joshua Tree Circle => Joshua Tree Circle
# Talon Circle => Talon Circle
# Belmont Circle => Belmont Circle
# Mooring Circle => Mooring Circle
# Celeste Circle => Celeste Circle
# Sandshof Circle => Sandshof Circle
# Chase Circle => Chase Circle
# Brandywine Circle => Brandywine Circle
# Willowbridge Circle => Willowbridge Circle
# Crest Ridge Circle => Crest Ridge Circle
# Denell Circle => Denell Circle
# Caravan Circle => Caravan Circle
# Marston Circle => Marston Circle
# Masters Circle => Masters Circle
# Mountbatten Circle => Mountbatten Circle
# Cadiz Circle => Cadiz Circle
# Murillo Circle => Murillo Circle
# Burly Oak Circle => Burly Oak Circle
# Quicksilver Circle => Quicksilver Circle
# Springmail Circle => Springmail Circle
# Tom Kite Circle => Tom Kite Circle
# Oak Meadow Circle => Oak Meadow Circle
# Deercreek Circle => Deercreek Circle
# Mosquero Circle => Mosquero Circle
# Beartree Circle => Beartree Circle
# Stage Stop Circle => Stage Stop Circle
# Stubble Quail Circle => Stubble Quail Circle
# Hitching Post Circle => Hitching Post Circle
# Park Thirty Five Circle => Park Thirty Five Circle
# Treaty Oak Circle => Treaty Oak Circle
# Brownlee Circle => Brownlee Circle
# Plumcreek Circle => Plumcreek Circle
# Hidden View Circle => Hidden View Circle
# Alcorn Circle => Alcorn Circle
# Ashland Circle => Ashland Circle
# Tahoe Parke Circle => Tahoe Parke Circle
# Lakefront Circle => Lakefront Circle
# Mesa Trails Circle => Mesa Trails Circle
# Coronado Circle => Coronado Circle
# Strader Circle => Strader Circle
# Stone Ridge Circle => Stone Ridge Circle
# Masthead Circle => Masthead Circle
# Bighorn Circle => Bighorn Circle
# Leaning Rock Circle => Leaning Rock Circle
# Radam Circle => Radam Circle
# Lakeview Circle => Lakeview Circle
# Burning Tree Circle => Burning Tree Circle
# Terraza Circle => Terraza Circle
# Silver Circle => Silver Circle
# Canyon Glen Circle => Canyon Glen Circle
# Canard Circle => Canard Circle
# Bronco Circle => Bronco Circle
# Holly Oak Circle => Holly Oak Circle
# Mosswood Circle => Mosswood Circle
# Brook Valley Circle => Brook Valley Circle
# Debba Circle => Debba Circle
# Chimney Creek Circle => Chimney Creek Circle
# Hyclimb Circle => Hyclimb Circle
# Seneca Circle => Seneca Circle
# Phillips Circle => Phillips Circle
# Tiber Circle => Tiber Circle
# Cedar Springs Circle => Cedar Springs Circle
# Hanging Oak Circle => Hanging Oak Circle
# Monmouth Circle => Monmouth Circle
# Lambert Circle => Lambert Circle
# Westbluff Circle => Westbluff Circle
# Silverhill Circle => Silverhill Circle
# Bruno Circle => Bruno Circle
# Encino Circle => Encino Circle
# Amy Circle => Amy Circle
# Skyway Circle => Skyway Circle
# Quartz Circle => Quartz Circle
# Round Mountain Circle => Round Mountain Circle
# Sambuca Circle => Sambuca Circle
# Birdwood Circle => Birdwood Circle
# Cliffwood Circle => Cliffwood Circle
# Map Circle => Map Circle
# Poteau Circle => Poteau Circle
# Paddington Circle => Paddington Circle
# Lazy Brook Circle => Lazy Brook Circle
# Wisteria Circle => Wisteria Circle
# Bolles Circle => Bolles Circle
# Dymalor Circle => Dymalor Circle
# Mandeville Circle => Mandeville Circle
# Oak Creek Circle => Oak Creek Circle
# Village Circle => Village Circle
# Gentilly Circle => Gentilly Circle
# Emerald Forest Circle => Emerald Forest Circle
# Cherry Tree Circle => Cherry Tree Circle
# Oliver Circle => Oliver Circle
# Egret Circle => Egret Circle
# Bunratty Circle => Bunratty Circle
# Orangewood Circle => Orangewood Circle
# Fountainbleu Circle => Fountainbleu Circle
# Cloudberry Circle => Cloudberry Circle
# Zopilote Circle => Zopilote Circle
# Mansfield Circle => Mansfield Circle
# Riata Vista Circle => Riata Vista Circle
# Overland Hills Circle => Overland Hills Circle
# Santa Cruz Circle => Santa Cruz Circle
# Quail Hill Circle => Quail Hill Circle
# Hyland Circle => Hyland Circle
# Transit Circle => Transit Circle
# Ridgeview Circle => Ridgeview Circle
# Chama Circle => Chama Circle
# Lost Ridge Circle => Lost Ridge Circle
# Dupree Circle => Dupree Circle
# Mission Hill Circle => Mission Hill Circle
# Belclaire Circle => Belclaire Circle
# Gem Circle => Gem Circle
# Travis Country Circle => Travis Country Circle
# Bluebonnet Circle => Bluebonnet Circle
# Apple Valley Circle => Apple Valley Circle
# Bat Hawk Circle => Bat Hawk Circle
# Canteen Circle => Canteen Circle
# Pinto Circle => Pinto Circle
# Timothy Circle => Timothy Circle
# Trone Circle => Trone Circle
# Valiant Circle => Valiant Circle
# Marks Circle => Marks Circle
# Hillspring Circle => Hillspring Circle
# Cade Circle => Cade Circle
# Bundyhill Circle => Bundyhill Circle
# Spiceland Circle => Spiceland Circle
# Juno Circle => Juno Circle
# Fora Circle => Fora Circle
# Rabbit Run Circle => Rabbit Run Circle
# Meadgreen Circle => Meadgreen Circle
# Windshill Circle => Windshill Circle
# Fathom Circle => Fathom Circle
# Benwick Circle => Benwick Circle
# Fawnridge Circle => Fawnridge Circle
# Spancreek Circle => Spancreek Circle
# Goeth Circle => Goeth Circle
# Cardinal Hill Circle => Cardinal Hill Circle
# Hidden Hill Circle => Hidden Hill Circle
# Breezeknoll Circle => Breezeknoll Circle
# Silverarrow Circle => Silverarrow Circle
# Bridlington Circle => Bridlington Circle
# Eleos Circle => Eleos Circle
# Willowood Circle => Willowood Circle
# Artesian Circle => Artesian Circle
# Diamond Head Circle => Diamond Head Circle
# Twin Ledge Circle => Twin Ledge Circle
# Mystic Oaks Circle => Mystic Oaks Circle
# Cornish Circle => Cornish Circle
# Merion Cricket Circle => Merion Cricket Circle
# Shumard Circle => Shumard Circle
# Colmenero Circle => Colmenero Circle
# Hilwin Circle => Hilwin Circle
# Knollpark Circle => Knollpark Circle
# Silverado Circle => Silverado Circle
# Buckhorn Circle => Buckhorn Circle
# Creeks Edge Circle => Creeks Edge Circle
# Grand Oak Circle => Grand Oak Circle
# Rising Hills Circle => Rising Hills Circle
# Dime Circle => Dime Circle
# Villa Oaks Circle => Villa Oaks Circle
# Nob Hill Circle => Nob Hill Circle
# Founders Circle => Founders Circle
# Live Oak Circle => Live Oak Circle
# Vigen Circle => Vigen Circle
# Hymeadow Circle => Hymeadow Circle
# Sunset Heights Circle => Sunset Heights Circle
# Lime Stone Circle => Lime Stone Circle
# Green Shore Circle => Green Shore Circle
# Rockwood Circle => Rockwood Circle
# Berwyn Circle => Berwyn Circle
# Mason Dixon Circle => Mason Dixon Circle
# Lakeridge Circle => Lakeridge Circle
# Windmill Circle => Windmill Circle
# Indian Quail Circle => Indian Quail Circle
# Glazier Circle => Glazier Circle
# Salt Block Circle => Salt Block Circle
# Silverplume Circle => Silverplume Circle
# Robinwood Circle => Robinwood Circle
# Orchard Park Circle => Orchard Park Circle
# Squirrel Oak Circle => Squirrel Oak Circle
# Valley High Circle => Valley High Circle
# Williamsburg Circle => Williamsburg Circle
# Candleberry Circle => Candleberry Circle
# Scenic Oaks Circle => Scenic Oaks Circle
# Honeycomb Rock Circle => Honeycomb Rock Circle
# Antelope Circle => Antelope Circle
# Harwill Circle => Harwill Circle
# Mini Circle => Mini Circle
# Thames Circle => Thames Circle
# Aberdeen Circle => Aberdeen Circle
# Alazan Circle => Alazan Circle
# Tophill Circle => Tophill Circle
# Socorro Circle => Socorro Circle
# Cree Circle => Cree Circle
# Laurel Creek Circle => Laurel Creek Circle
# Commodore Circle => Commodore Circle
# Leaning Oak Circle => Leaning Oak Circle
# Honeycomb Circle => Honeycomb Circle
# Mc Carthy Circle => Mc Carthy Circle
# Bent Oak Circle => Bent Oak Circle
# Silvercrest Circle => Silvercrest Circle
# Valleyridge Circle => Valleyridge Circle
# Clemente Circle => Clemente Circle
# Bunyon Circle => Bunyon Circle
# Highland Hills Circle => Highland Hills Circle
# Javelina Circle => Javelina Circle
# Meadow Creek Circle => Meadow Creek Circle
# Verde Bank Circle => Verde Bank Circle
# Lakeland Circle => Lakeland Circle
# North Scout Island Circle => North Scout Island Circle
# Sagebrush Circle => Sagebrush Circle
# Montoya Circle => Montoya Circle
# Grove Crest Circle => Grove Crest Circle
# Lomita Verde Circle => Lomita Verde Circle
# Carefree Circle => Carefree Circle
# Vinca Circle => Vinca Circle
# Welland Circle => Welland Circle
# Rampart Circle => Rampart Circle
# Sunset Circle => Sunset Circle
# Jekel Circle => Jekel Circle
# Hubbard Circle => Hubbard Circle
# Windy Trail Circle => Windy Trail Circle
# Konstanty Circle => Konstanty Circle
# Woodmoor Circle => Woodmoor Circle
# Gunsmoke Circle => Gunsmoke Circle
# Sage Hen Circle => Sage Hen Circle
# Culebra Circle => Culebra Circle
# Abbey Circle => Abbey Circle
# Matador Circle => Matador Circle
# East Leslie Circle => East Leslie Circle
# Oakwood Circle => Oakwood Circle
# Cooper Circle => Cooper Circle
# Partage Circle => Partage Circle
# Mathis Circle => Mathis Circle
# Mesa Verde Circle => Mesa Verde Circle
# Kafka Circle => Kafka Circle
# Spotted Owl Circle => Spotted Owl Circle
# Cypress Knee Circle => Cypress Knee Circle
# Fort Sumter Circle => Fort Sumter Circle
# Ironwood Circle => Ironwood Circle
# Randy Circle => Randy Circle
# Bull Run Circle => Bull Run Circle
# Beckett Circle => Beckett Circle
# Prairie Dove Circle => Prairie Dove Circle
# Barranca Circle => Barranca Circle
# Westslope Circle => Westslope Circle
# Eanes Circle => Eanes Circle
# Dorsett Oaks Circle => Dorsett Oaks Circle
# Northland Circle => Northland Circle
# Crownspoint Circle => Crownspoint Circle
# Maplewood Circle => Maplewood Circle
# Burnside Circle => Burnside Circle
# Red Oak Circle => Red Oak Circle
# Golden Hills Circle => Golden Hills Circle
# Iguana Circle => Iguana Circle
# Tawny Circle => Tawny Circle
# Arronimink Circle => Arronimink Circle
# Cottonwood Circle => Cottonwood Circle
# Aldford Circle => Aldford Circle
# Tolstoy Circle => Tolstoy Circle
# Gungrove Circle => Gungrove Circle
# Pringle Circle => Pringle Circle
# Boca Chica Circle => Boca Chica Circle
# Endeavor Circle => Endeavor Circle
# Laurel Circle => Laurel Circle
# Dawn Hill Circle => Dawn Hill Circle
# Village Trail Circle => Village Trail Circle
# Willowwick Circle => Willowwick Circle
# Marlborough Circle => Marlborough Circle
# Disraeli Circle => Disraeli Circle
# Brookwood Circle => Brookwood Circle
# Coral Ridge Circle => Coral Ridge Circle
# Sunnylawn Circle => Sunnylawn Circle
# Baxter Circle => Baxter Circle
# Village Creek Circle => Village Creek Circle
# Oakmountain Circle => Oakmountain Circle
# Cone Circle => Cone Circle
# Timber Creek Circle => Timber Creek Circle
# Saddle Circle => Saddle Circle
# Union Circle => Union Circle
# Sam Houston Circle => Sam Houston Circle
# Saint John's Circle => Saint John's Circle
# Blueberry Circle => Blueberry Circle
# Lyra Circle => Lyra Circle
# Meadow Circle => Meadow Circle
# Citation Circle => Citation Circle
# Cocao Circle => Cocao Circle
# Parkview Circle => Parkview Circle
# Butler Circle => Butler Circle
# Glowworm Circle => Glowworm Circle
# Summer Wind Circle => Summer Wind Circle
# Rockingham Circle => Rockingham Circle
# Woodlake Circle => Woodlake Circle
# Rockcrest Circle => Rockcrest Circle
# Bluebell Circle => Bluebell Circle
# Enclave Mesa Circle => Enclave Mesa Circle
# Prestonwood Circle => Prestonwood Circle
# Rustling Circle => Rustling Circle
# Spotted Fawn Circle => Spotted Fawn Circle
# Mustang Island Circle => Mustang Island Circle
# Elm Grove Circle => Elm Grove Circle
# De Soto Circle => De Soto Circle
# Cedar Ridge Circle => Cedar Ridge Circle
# Gallo Circle => Gallo Circle
# Chatsworth Circle => Chatsworth Circle
# Minot Circle => Minot Circle
# Silverleaf Circle => Silverleaf Circle
# Pebblestone Circle => Pebblestone Circle
# Bee Hill Circle => Bee Hill Circle
# Chalet Circle => Chalet Circle
# Wilton Circle => Wilton Circle
# Dueling Oak Circle => Dueling Oak Circle
# Headway Circle => Headway Circle
# Helmway Circle => Helmway Circle
# Pescado Circle => Pescado Circle
# Mountain Villa Circle => Mountain Villa Circle
# Clearsky Circle => Clearsky Circle
# Knollwood Circle => Knollwood Circle
# Glenhaven Circle => Glenhaven Circle
# Craybrough Circle => Craybrough Circle
# Current Circle => Current Circle
# Huntridge Circle => Huntridge Circle
# Brock Circle => Brock Circle
# Oxbow Circle => Oxbow Circle
# Teck Circle => Teck Circle
# Dumaine Circle => Dumaine Circle
# Thurgood Circle => Thurgood Circle
# Wildwood Circle => Wildwood Circle
# Wild Oak Circle => Wild Oak Circle
# Cherrylawn Circle => Cherrylawn Circle
# Ledgerock Circle => Ledgerock Circle
# Deep Circle => Deep Circle
# Dillard Circle => Dillard Circle
# Mountain Top Circle => Mountain Top Circle
# Begonia Circle => Begonia Circle
# Chukar Circle => Chukar Circle
# Star Grass Circle => Star Grass Circle
# Stonecliff Circle => Stonecliff Circle
# Clarewood Circle => Clarewood Circle
# Tern Circle => Tern Circle
# Waterton Parke Circle => Waterton Parke Circle
# Timber Circle => Timber Circle
# Poe Circle => Poe Circle
# Wood Ibis Circle => Wood Ibis Circle
# Hundred Oaks Circle => Hundred Oaks Circle
# Arbor Circle => Arbor Circle
# Metairie Circle => Metairie Circle
# Pinehurst Circle => Pinehurst Circle
# Utah Circle => Utah Circle
# Irongate Circle => Irongate Circle
# Thousand Oaks Circle => Thousand Oaks Circle
# Vista View Circle => Vista View Circle
# Lakeshore Circle => Lakeshore Circle
# Boffi Circle => Boffi Circle
# Stableford Circle => Stableford Circle
# Sandringham Circle => Sandringham Circle
# Blanco Circle => Blanco Circle
# Eric Circle => Eric Circle
# Town Lake Circle => Town Lake Circle
# Shawnee Circle => Shawnee Circle
# Walton Heath Circle => Walton Heath Circle
# Stuart Circle => Stuart Circle
# Devon Circle => Devon Circle
# Bundy Crest Circle => Bundy Crest Circle
# Brown Bluff Circle => Brown Bluff Circle
# Trail Crest Circle => Trail Crest Circle
# Blake Manor Circle => Blake Manor Circle
# Mesa Oaks Circle => Mesa Oaks Circle
# Channing Circle => Channing Circle
# Stonehaven Circle => Stonehaven Circle
# Carbine Circle => Carbine Circle
# Travis Circle => Travis Circle
# Rose Hill Circle => Rose Hill Circle
# Elder Circle => Elder Circle
# Clivden Circle => Clivden Circle
# Marywood Circle => Marywood Circle
# Apple Vista Circle => Apple Vista Circle
# South Ridge Circle => South Ridge Circle
# Westgate Circle => Westgate Circle
# Deer Ridge Circle => Deer Ridge Circle
# Rush Pea Circle => Rush Pea Circle
# Bell Rock Circle => Bell Rock Circle
# Bramble Bush Circle => Bramble Bush Circle
# Towana Circle => Towana Circle
# Big Horn Circle => Big Horn Circle
# Stone Gate Circle => Stone Gate Circle
# Steamline Circle => Steamline Circle
# Oakleaf Circle => Oakleaf Circle
# Wickford Circle => Wickford Circle
# Esplanade Circle => Esplanade Circle
# Running Rope Circle => Running Rope Circle
# Libyan Circle => Libyan Circle
# Barton Village Circle => Barton Village Circle
# Ten Oaks Circle => Ten Oaks Circle
# Greenslope Circle => Greenslope Circle
# Ferndale Circle => Ferndale Circle
# Lakehead Circle => Lakehead Circle
# Foley Circle => Foley Circle
# Reeves Circle => Reeves Circle
# Northwood Circle => Northwood Circle
# Chicadee Circle => Chicadee Circle
# Yaupon Springs Circle => Yaupon Springs Circle
# Rita Blanca Circle => Rita Blanca Circle
# Little Oak Circle => Little Oak Circle
# Rockdale Circle => Rockdale Circle
# Freemont Circle => Freemont Circle
# Currywood Circle => Currywood Circle
# Mountain Path Circle => Mountain Path Circle
# Newfoundland Circle => Newfoundland Circle
# Edwin Reinhardt => Edwin Reinhardt
# Roaring Fork => Roaring Fork
# Hilldale => Hilldale
# Meadow Ford => Meadow Ford
# Sunterro => Sunterro
# Silver Spur => Silver Spur
# Rutledge Spur => Rutledge Spur
# Lohmans Spur => Lohmans Spur
# Quick Fort => Quick Fort
# W. Anderson Lane, Suite A-15 => West Anderson Lane, Suite A-15
# Farm-to-Market Road 2769 => Farm-to-Market Road 2769
# Woodrow Ave. => Woodrow Avenue
# Sioux => Sioux
# Inland Greens => Inland Greens
# Avenue K => Avenue K
# Palace Green => Palace Green
# Saint Georges Green => Saint Georges Green
# Bear Claw => Bear Claw
# Jollyville Road Suite 100 => Jollyville Road Suite 100
# RM 2222 Unit #100 => RM 2222 Unit #100
# Old Jollyville Road, Suite 100 => Old Jollyville Road, Suite 100
# 4207 James Casey st #101 => 4207 James Casey st #101
# 11410 Century Oaks Terrace Suite #104 => 11410 Century Oaks Terrace Suite #104
# Arroyo Claro => Arroyo Claro
# Mirador => Mirador
# Lake Clark => Lake Clark
# Liberty Grotto => Liberty Grotto
# N. IH35, => North IH35,
# N IH 35 => North IH 35
# N. IH 35 => North IH 35
# South Interstate 35 => South Interstate 35
# S Interstate 35 => South Interstate 35
# N Interstate Highway 35 => North Interstate Highway 35
# North IH 35 => North IH 35
# Interstate 35 => Interstate 35
# North Interstate Highway 35 => North Interstate Highway 35
# I 35 => I 35
# S Interstate Highway 35 => South Interstate Highway 35
# 9600 S IH 35 => 9600 South IH 35
# Interstate Highway 35 => Interstate Highway 35
# Avenue N => Avenue North
# Capital of TX Hwy N => Capital of TX Highway North
# Farm to Market 620 N => Farm to Market 620 North
# Calle Limon => Calle Limon
# Creek Mountain => Creek Mountain
# Pecan St. => Pecan Street
# Guadalupe St. => Guadalupe Street
# E. 43rd St. => East 43rd Street
# E 38th 1/2 St. => East 38th 1/2 Street
# Camelback => Camelback
# Green Acres => Green Acres
# Clearwater => Clearwater
# Michael Dale => Michael Dale
# Old Walsh Tarlton => Old Walsh Tarlton
# Pasa Tiempo => Pasa Tiempo
# Green Lanes => Green Lanes
# Explorer => Explorer
# N IH 35 Bldg. 6 => North IH 35 Bldg. 6
# Gunsmoke => Gunsmoke
# Dream Catcher => Dream Catcher
# Avenue F => Avenue F
# Voyageurs => Voyageurs
# Shepherds Corral => Shepherds Corral
# O K Corral => O K Corral
# Raglan CastlePath => Raglan CastlePath
# FM 1626 => FM 1626
# Farm-to-Market Road 1626 => Farm-to-Market Road 1626
# F.M. 1626 => F.M. 1626
# Farm-to-Market Road 1625 => Farm-to-Market Road 1625
# Leafdale Point => Leafdale Point
# Arrowhead Point => Arrowhead Point
# Eagle Point => Eagle Point
# Moss Point => Moss Point
# Craggy Point => Craggy Point
# Klondike Rush Point => Klondike Rush Point
# Hunterwood Point => Hunterwood Point
# Cliff Point => Cliff Point
# Lookout Point => Lookout Point
# Mariners Point => Mariners Point
# Osage Point => Osage Point
# Signal Point => Signal Point
# Blue Jay Point => Blue Jay Point
# Mediterra Point => Mediterra Point
# Kings Point => Kings Point
# Yellow Sage => Yellow Sage
# Mount Bonnell Hollow => Mount Bonnell Hollow
# Beechwood Hollow => Beechwood Hollow
# Wild Cat Hollow => Wild Cat Hollow
# Jessamine Hollow => Jessamine Hollow
# Maury Hollow => Maury Hollow
# Cave Hollow => Cave Hollow
# Dogwood Hollow => Dogwood Hollow
# Cedar Hollow => Cedar Hollow
# Grass Hollow => Grass Hollow
# Firewheel Hollow => Firewheel Hollow
# Hudson Hollow => Hudson Hollow
# Quail Hollow => Quail Hollow
# Balsam Hollow => Balsam Hollow
# Black Mesa Hollow => Black Mesa Hollow
# Lakewood Hollow => Lakewood Hollow
# Pepper Mill Hollow => Pepper Mill Hollow
# Fern Hollow => Fern Hollow
# Bittern Hollow => Bittern Hollow
# Winecup Hollow => Winecup Hollow
# Knapp Hollow => Knapp Hollow
# Turkey Hollow => Turkey Hollow
# Coachwhip Hollow => Coachwhip Hollow
# Sunset Hollow => Sunset Hollow
# Twin Creek Hollow => Twin Creek Hollow
# Salt Mill Hollow => Salt Mill Hollow
# Haley Hollow => Haley Hollow
# Logans Hollow => Logans Hollow
# Brushy Hollow => Brushy Hollow
# Chestnut Hollow => Chestnut Hollow
# Squirrel Hollow => Squirrel Hollow
# Hickory Hollow => Hickory Hollow
# Autumnleaf Hollow => Autumnleaf Hollow
# Big Oak Hollow => Big Oak Hollow
# Hideaway Hollow => Hideaway Hollow
# Red Mesa Hollow => Red Mesa Hollow
# Gardenridge Hollow => Gardenridge Hollow
# Lantana Hollow => Lantana Hollow
# Horseback Hollow => Horseback Hollow
# Hood Hollow => Hood Hollow
# Creek Hollow => Creek Hollow
# Honeycomb Hollow => Honeycomb Hollow
# Sandalwood Hollow => Sandalwood Hollow
# Apple Springs Hollow => Apple Springs Hollow
# Pecan Hollow => Pecan Hollow
# Breeze Hollow => Breeze Hollow
# Gold Flower Hollow => Gold Flower Hollow
# Mill Hollow => Mill Hollow
# Hurst Hollow => Hurst Hollow
# Hidden Hollow => Hidden Hollow
# Secluded Hollow => Secluded Hollow
# Dewberry Hollow => Dewberry Hollow
# Lost Oasis Hollow => Lost Oasis Hollow
# Paintbrush Hollow => Paintbrush Hollow
# Bold Sundown => Bold Sundown
# South I-35 Service SB => South I-35 Service SB
# Mustang => Mustang
# Sendera Bonita => Sendera Bonita
# Calhoun Ln => Calhoun Lane
# Sky Ridge Ln => Sky Ridge Lane
# Violet Ln => Violet Lane
# Pasadera Ln => Pasadera Lane
# Comfort Ln => Comfort Lane
# Grazing Horse Ln => Grazing Horse Lane
# Wind Tree Ln => Wind Tree Lane
# Majestic Elm Ln => Majestic Elm Lane
# Buzz Schneider Ln => Buzz Schneider Lane
# Sierra Wind Ln => Sierra Wind Lane
# Rocky Top Ln => Rocky Top Lane
# Chick Pea Ln => Chick Pea Lane
# Prairie Verbena Ln => Prairie Verbena Lane
# Cloudmore Ln => Cloudmore Lane
# Timber Arch Ln => Timber Arch Lane
# Laguna Seca Ln => Laguna Seca Lane
# Floribundas Ln => Floribundas Lane
# Honey Locust Ln => Honey Locust Lane
# West Parmer Ln => West Parmer Lane
# Hidden Hills Ln => Hidden Hills Lane
# Rockwood Ln => Rockwood Lane
# W Anderson Ln => West Anderson Lane
# Hillhouse Ln => Hillhouse Lane
# Mahonia Ln => Mahonia Lane
# Via Media => Via Media
# Wagon Wheel => Wagon Wheel
# Fleming court => Fleming Court
# West William Cannon => West William Cannon
# Hambletonian => Hambletonian
# El Viejo Camino => El Viejo Camino
# Springwater => Springwater
# River Birch => River Birch
# Falcon => Falcon
# Eagle Cliff => Eagle Cliff
# Gila Cliff => Gila Cliff
# Avenue A => Avenue A
# 9600 IH 35 C-200 => 9600 IH 35 C-200
# Laughing Dog => Laughing Dog
# Running Rope => Running Rope
# Fandango => Fandango
# Woody Ridge View => Woody Ridge View
# Hurst View => Hurst View
# Pleasant Panorama View => Pleasant Panorama View
# Valley View => Valley View
# Canyon View => Canyon View
# Rotunda View => Rotunda View
# Key View => Key View
# Summit View => Summit View
# Morning View => Morning View
# Sunset View => Sunset View
# La Fauna View => La Fauna View
# Sea Eagle View => Sea Eagle View
# Panoramic View => Panoramic View
# South Congress Avene => South Congress Avene
# Highlander => Highlander
# Farm to Market 685 => Farm to Market 685
# FM 685 => FM 685
# Stonebridge => Stonebridge
# Burnet Rd Ste, A500 => Burnet Road Ste, A500
# Creek Bottom => Creek Bottom
# Gonzales => Gonzales
# W US Highway 290 Service Rd => West U.S. Highway 290 Service Road
# Red Pebble Rd => Red Pebble Road
# Barley Rd => Barley Road
# Barton Springs Rd => Barton Springs Road
# Moon Rock Rd => Moon Rock Road
# Bee Creek Rd => Bee Creek Road
# N Interstate 35 Frontage Rd => North Interstate 35 Frontage Road
# Spicewood Springs Rd => Spicewood Springs Road
# Big Meadow Rd => Big Meadow Road
# Palomino Ranch Rd => Palomino Ranch Road
# Commons Rd => Commons Road
# Burnet Rd => Burnet Road
# Tawny Farms Rd => Tawny Farms Road
# Switch Willo => Switch Willo
# Mesa Oaks => Mesa Oaks
# Sierra Oaks => Sierra Oaks
# County Road 138 => County Road 138
# N. Lamar suite#L131 => North Lamar suite#L131
# Longhorn Landing => Longhorn Landing
# Richfield Landing => Richfield Landing
# North Highway 183 #406 => North Highway 183 #406
# North Lakeline Boulevard, Ste. 400 => North Lakeline Boulevard, Ste. 400
# Edenderry => Edenderry
# Circle Haven => Circle Haven
# Troll Haven => Troll Haven
# 9901 N Capital Of texas => 9901 North Capital Of texas
# Ranch to Market Road 2222 => Ranch to Market Road 2222
# Calle Caliche => Calle Caliche
# High Lonesome => High Lonesome
# Messenger Stakes => Messenger Stakes
# Rue de St Tropez => Rue de Street Tropez
# Twin Saddles => Twin Saddles
# Sandpiper => Sandpiper
# The Living End => The Living End
# Indiana Dunes => Indiana Dunes
# Pow Wow => Pow Wow
# W. Liberty => West Liberty
# Paw Print => Paw Print
# Tortilla Flat => Tortilla Flat
# Wet Season => Wet Season
# Prince William => Prince William
# Seawind => Seawind
# N I H 35 Bldg 7 => North I H 35 Bldg 7
# Camino Viejo => Camino Viejo
# RM1431 => RM1431
# Avenue G => Avenue G
# China Grove => China Grove
# Palma Plaza => Palma Plaza
# Amy Donovan Plaza => Amy Donovan Plaza
# Oak Plaza => Oak Plaza
# North Plaza => North Plaza
# Park Plaza => Park Plaza
# Centre Plaza => Centre Plaza
# I35 => I35
# La Cantera => La Cantera
# Highway 71 W => Highway 71 West
# Hwy 290 W => Highway 290 West
# Farm-to-Market Road 973 => Farm-to-Market Road 973
# Tandem Blvd. => Tandem Boulevard
# South Lamar Blvd. => South Lamar Boulevard
# South Exposition Blvd. => South Exposition Boulevard
# W North Loop Blvd. => West North Loop Boulevard
# East Old Settlers Blvd. => East Old Settlers Boulevard
# Research Blvd. => Research Boulevard
# Old Farm-to-Market 1431 => Old Farm-to-Market 1431
# Farm-to-Market Road 1431 => Farm-to-Market Road 1431
# Big Horn => Big Horn
# Austrina Pass => Austrina Pass
# San Juan Pass => San Juan Pass
# Chisos Pass => Chisos Pass
# Pack Saddle Pass => Pack Saddle Pass
# Smoke Signal Pass => Smoke Signal Pass
# Petrove Pass => Petrove Pass
# Branding Iron Pass => Branding Iron Pass
# Durango Pass => Durango Pass
# Arrowhead Pass => Arrowhead Pass
# Maulding Pass => Maulding Pass
# Black Gap Pass => Black Gap Pass
# Quadros Pass => Quadros Pass
# Ravello Pass => Ravello Pass
# Berryessa Pass => Berryessa Pass
# Outrider Pass => Outrider Pass
# Serene Hills Pass => Serene Hills Pass
# Jacks Pass => Jacks Pass
# Buckskin Pass => Buckskin Pass
# Raton Pass => Raton Pass
# Kenosha Pass => Kenosha Pass
# Siringo Pass => Siringo Pass
# Wild Briar Pass => Wild Briar Pass
# Quiet Water Pass => Quiet Water Pass
# Alegre Pass => Alegre Pass
# Payload Pass => Payload Pass
# Arapahoe Pass => Arapahoe Pass
# Belfry Pass => Belfry Pass
# Oasis Pass => Oasis Pass
# Passionflower Pass => Passionflower Pass
# White Dove Pass => White Dove Pass
# Temecula Pass => Temecula Pass
# Bill Hickcock Pass => Bill Hickcock Pass
# Sailboat Pass => Sailboat Pass
# Salida del Sol Pass => Salida del Sol Pass
# Quitman Pass => Quitman Pass
# Wild Turkey Pass => Wild Turkey Pass
# Sunken Creek Pass => Sunken Creek Pass
# Overlook Pass => Overlook Pass
# Turks Cap Pass => Turks Cap Pass
# Red Deer Pass => Red Deer Pass
# Couri Pass => Couri Pass
# Gunnison Pass => Gunnison Pass
# Highland Pass => Highland Pass
# Overland Pass => Overland Pass
# Dawn River Pass => Dawn River Pass
# Arrowmound Pass => Arrowmound Pass
# Wolfcreek Pass => Wolfcreek Pass
# Pyrenees Pass => Pyrenees Pass
# Covered Wagon Pass => Covered Wagon Pass
# Eagle Pass => Eagle Pass
# Huebinger Pass => Huebinger Pass
# Navajo Pass => Navajo Pass
# Sly Pass => Sly Pass
# Trophy Pass => Trophy Pass
# Pontic Pass => Pontic Pass
# Kiowa Pass => Kiowa Pass
# Montana Ridge Pass => Montana Ridge Pass
# Poppy Pass => Poppy Pass
# Teton Pass => Teton Pass
# Double Eagle Pass => Double Eagle Pass
# Lakota Pass => Lakota Pass
# Sam Maverick Pass => Sam Maverick Pass
# Mid Bark Pass => Mid Bark Pass
# Pawnee Pass => Pawnee Pass
# Ferrystone Pass => Ferrystone Pass
# Maritime Pass => Maritime Pass
# Broken Bow Pass => Broken Bow Pass
# Bloomfield Hills Pass => Bloomfield Hills Pass
# Paul Jones Pass => Paul Jones Pass
# Latigo Pass => Latigo Pass
# High Canyon Pass => High Canyon Pass
# Westlake Pass => Westlake Pass
# Irby Pass => Irby Pass
# Melba Pass => Melba Pass
# Apache Pass => Apache Pass
# Lakewood Hills Pass => Lakewood Hills Pass
# Lone Mountain Pass => Lone Mountain Pass
# Barley Field Pass => Barley Field Pass
# Telegraph Pass => Telegraph Pass
# Masterson Pass => Masterson Pass
# Piedmont Hills Pass => Piedmont Hills Pass
# Clay Allison Pass => Clay Allison Pass
# Bullet Pass => Bullet Pass
# Pavelich Pass => Pavelich Pass
# Breezy Pass => Breezy Pass
# Buffalo Pass => Buffalo Pass
# Hogg Pecan Pass => Hogg Pecan Pass
# Timber Ridge Pass => Timber Ridge Pass
# Dan Pass => Dan Pass
# Gila Pass => Gila Pass
# Trace Creek Pass => Trace Creek Pass
# Gift Horse Pass => Gift Horse Pass
# Corner Brook Pass => Corner Brook Pass
# Crazyhorse Pass => Crazyhorse Pass
# Strontian Pass => Strontian Pass
# Patagonia Pass => Patagonia Pass
# Amber Pass => Amber Pass
# Blanco River Pass => Blanco River Pass
# Continental Pass => Continental Pass
# Timber Pass => Timber Pass
# Kinder Pass => Kinder Pass
# Hunters Pass => Hunters Pass
# Bird Call Pass => Bird Call Pass
# Thornwild Pass => Thornwild Pass
# Platte Pass => Platte Pass
# Splendor Pass => Splendor Pass
# Ebony Hollow Pass => Ebony Hollow Pass
# Davis Mountain Pass => Davis Mountain Pass
# Walton Hill Pass => Walton Hill Pass
# Saddle Back Pass => Saddle Back Pass
# Whitetail Pass => Whitetail Pass
# Grider Pass => Grider Pass
# Long Lasso Pass => Long Lasso Pass
# Barker Hollow Pass => Barker Hollow Pass
# Snowbird Pass => Snowbird Pass
# Wildcat Pass => Wildcat Pass
# Wyoming Pass => Wyoming Pass
# Cielo Azul Pass => Cielo Azul Pass
# Martinique Pass => Martinique Pass
# Overton Pass => Overton Pass
# Billy Bonney Pass => Billy Bonney Pass
# Ruskin Pass => Ruskin Pass
# Deer Pass => Deer Pass
# Plain Rock Pass => Plain Rock Pass
# Cottage Grove Pass => Cottage Grove Pass
# Phoenix Pass => Phoenix Pass
# Lookout Cliff Pass => Lookout Cliff Pass
# Poncha Pass => Poncha Pass
# La Concha Pass => La Concha Pass
# Golddust Pass => Golddust Pass
# Majestic Oaks Pass => Majestic Oaks Pass
# Rio Pass => Rio Pass
# County Road 459 => County Road 459
# RM 620 => RM 620
# FM 620 => FM 620
# N FM 620 => North FM 620
# Ranch Road 620 => Ranch Road 620
# Ranch-to-Market Road 620 => Ranch-to-Market Road 620
# RR 620 => RR 620
# Real Catorce => Real Catorce
# County Road 170 => County Road 170
# Lido => Lido
# N Mopac Expwy => North Mopac Expwy
# Montana Norte => Montana Norte
# Ladera Norte => Ladera Norte
# East Meadow Vale => East Meadow Vale
# US 183 => U.S. 183
# US Highway 183 => U.S. Highway 183
# U.S. 183 => U.S. 183
# N HWY 183 => North Highway 183
# United States Highway 183 => United States Highway 183
# Barton Skyway => Barton Skyway
# Longhorn Skyway => Longhorn Skyway
# Picadilly => Picadilly
# Bachelor Gulch => Bachelor Gulch
# Thunder Gulch => Thunder Gulch
# Grubstake Gulch => Grubstake Gulch
# Hidden Mesa => Hidden Mesa
# Lone Mesa => Lone Mesa
# Spicewood Mesa => Spicewood Mesa
# Mustang Mesa => Mustang Mesa
# Alta Mesa => Alta Mesa
# Via Fortuna => Via Fortuna
# Avenue B => Avenue B
# Chimney Corners => Chimney Corners
# Tall Withers => Tall Withers
# Indian Summit => Indian Summit
# Hitching Post => Hitching Post
# Sidewinder => Sidewinder
# Ranch to Market Road 12 => Ranch to Market Road 12
# Sierra Colorado => Sierra Colorado
# Ventana Canyon => Ventana Canyon
# Critter Canyon => Critter Canyon
# Ambush Canyon => Ambush Canyon
# Spearfish Canyon => Spearfish Canyon
# Shadow Canyon => Shadow Canyon
# Long Arrow Canyon => Long Arrow Canyon
# Galaxy => Galaxy
# West 11th Street, Suite 275 => West 11th Street, Suite 275
# Paseo del Toro => Paseo del Toro
# Canterwood => Canterwood
# Warbler Ledge => Warbler Ledge
# Basin Ledge => Basin Ledge
# Deer Creek Skyview => Deer Creek Skyview
# Smokey Valley => Smokey Valley
# Spurlock Valley => Spurlock Valley
# Lost Valley => Lost Valley
# Green Valley => Green Valley
# Piland Triangle => Piland Triangle
# Sky Kiss => Sky Kiss
# Woodall Dr => Woodall Drive
# Round Rock West Dr => Round Rock West Drive
# Wylie Dr => Wylie Drive
# Ozona Dr => Ozona Drive
# Yaupon Range Dr => Yaupon Range Drive
# Lighthouse Landing Dr => Lighthouse Landing Drive
# China Rose Dr => China Rose Drive
# Via Dono Dr => Via Dono Drive
# W Lake Dr => West Lake Drive
# Camperdown Elm Dr => Camperdown Elm Drive
# Park at Woodlands Dr => Park at Woodlands Drive
# W William Cannon Dr => West William Cannon Drive
# Dave Silk Dr => Dave Silk Drive
# Forest Creek Dr => Forest Creek Drive
# Ashbrook Dr => Ashbrook Drive
# Corral de Tierra Dr => Corral de Tierra Drive
# Ivy Dr => Ivy Drive
# Aviation Dr => Aviation Drive
# Sun Shower Bend => Sun Shower Bend
# Magee Bend => Magee Bend
# Cactus Bend => Cactus Bend
# Barrel Bend => Barrel Bend
# Concho Creek Bend => Concho Creek Bend
# Bonaparte Bend => Bonaparte Bend
# Bay City Bend => Bay City Bend
# West Custers Creek Bend => West Custers Creek Bend
# Bar Harbor Bend => Bar Harbor Bend
# Izoro Bend => Izoro Bend
# Melekhin Bend => Melekhin Bend
# Banbury Bend => Banbury Bend
# Parker Bend => Parker Bend
# Bangor Bend => Bangor Bend
# La Barzola Bend => La Barzola Bend
# Bantom Woods Bend => Bantom Woods Bend
# Basket Flower Bend => Basket Flower Bend
# Canola Bend => Canola Bend
# Bayou Bend => Bayou Bend
# Giblin Bend => Giblin Bend
# Sunset Strip => Sunset Strip
# West Louis Henna Blvd => West Louis Henna Boulevard
# Airport Blvd => Airport Boulevard
# Swenson Farms Blvd => Swenson Farms Boulevard
# Industrial Oaks Blvd => Industrial Oaks Boulevard
# N Bell Blvd => North Bell Boulevard
# North Lamar Blvd => North Lamar Boulevard
# Industrial Blvd => Industrial Boulevard
# N. Lamar Blvd => North Lamar Boulevard
# Stonelake Blvd => Stonelake Boulevard
# Escarpment Blvd => Escarpment Boulevard
# South Lamar Blvd => South Lamar Boulevard
# South Bell Blvd => South Bell Boulevard
# Research Blvd => Research Boulevard
# North Research Blvd => North Research Boulevard
# W Hwy 71, STE D1 => West Highway 71, STE D1
# Panorama Ridge => Panorama Ridge
# Creek Ridge => Creek Ridge
# Cedar Ridge => Cedar Ridge
# South Ridge => South Ridge
# Runners Ridge => Runners Ridge
# Timberline Ridge => Timberline Ridge
# Wilder Ridge => Wilder Ridge
# Pumpkin Ridge => Pumpkin Ridge
# Ashton Ridge => Ashton Ridge
# Honeycomb Ridge => Honeycomb Ridge
# Riker Ridge => Riker Ridge
# Points West Ridge => Points West Ridge
# Carson Ridge => Carson Ridge
# Mission Ridge => Mission Ridge
# Smoky Ridge => Smoky Ridge
# Mesa Ridge => Mesa Ridge
# Buckskin Ridge => Buckskin Ridge
# Ringtail Ridge => Ringtail Ridge
# Murchison Ridge => Murchison Ridge
# Musket Ridge => Musket Ridge
# Sunset Ridge => Sunset Ridge
# Points East Ridge => Points East Ridge
# Hacienda Ridge => Hacienda Ridge
# North Ridge => North Ridge
# Aria Ridge => Aria Ridge
# Sandy Ridge => Sandy Ridge
# Parade Ridge => Parade Ridge
# Pantera Ridge => Pantera Ridge
# Cantina Sky => Cantina Sky
# ...
# Edenvale Path => Edenvale Path
# Ferret Path => Ferret Path
# War Path => War Path
# Sean Avery Path => Sean Avery Path
# West Cow Path => West Cow Path
# Village Path => Village Path
# Glenhollow Path => Glenhollow Path
# Kirkland Hill Path => Kirkland Hill Path
# Navajo Path => Navajo Path
# Pin Oak Path => Pin Oak Path
# Pinto Path => Pinto Path
# Miss Adrienne's Path => Miss Adrienne's Path
# Daisy Path => Daisy Path
# Pebble Path => Pebble Path
# Parell Path => Parell Path
# Cork Path => Cork Path
# Ozarks Path => Ozarks Path
# Nevada Path => Nevada Path
# Stokesay Castle Path => Stokesay Castle Path
# Crown Ridge Path => Crown Ridge Path
# Little Dipper Path => Little Dipper Path
# Quail Ravine => Quail Ravine
# Mariner => Mariner
# Old Stonehedge => Old Stonehedge
# Porpoise => Porpoise
# Dalmahoy => Dalmahoy
# Medalist => Medalist
# Vail Divide => Vail Divide
# Misty Heights Cc => Misty Heights Cc
# FM 969 => FM 969
# Camino Arbolago => Camino Arbolago
# Farm-to-Market Road 1100 => Farm-to-Market Road 1100
# Lake Mist => Lake Mist
# Blue Sky Cv => Blue Sky Cove
# Texas Ash Cv => Texas Ash Cove
# Tom Kite Cv => Tom Kite Cove
# Quiet Meadows Cv => Quiet Meadows Cove
# Peat Moors Cv => Peat Moors Cove
# La Estrella Cv => La Estrella Cove
# Morning Primrose Cv => Morning Primrose Cove
# Mallard Cv => Mallard Cove
# Rooney Cv => Rooney Cove
# Copper Point Cv => Copper Point Cove
# Old Corral Cv => Old Corral Cove
# Red River Cv => Red River Cove
# Secluded Willow Cv => Secluded Willow Cove
# Hilltop Canyon Cv => Hilltop Canyon Cove
# Hal Sutton Cv => Hal Sutton Cove
# La Roca Cv => La Roca Cove
# Arbole Cv => Arbole Cove
# Clear Pond Cv => Clear Pond Cove
# Salem Oak Cv => Salem Oak Cove
# Ripley Castle Cv => Ripley Castle Cove
# Enchanted Cv => Enchanted Cove
# Lapin Cv => Lapin Cove
# Mock Cherry Cv => Mock Cherry Cove
# Claro Vista Ct => Claro Vista Court
# Ash Tree Ct => Ash Tree Court
# Ely Ct => Ely Court
# Hill Stable Ct => Hill Stable Court
# Krupa Ct => Krupa Court
# Sterling Heights Ct => Sterling Heights Court
# Sweetgum Ct => Sweetgum Court
# Costello Ct => Costello Court
# Stirling Castle Ct => Stirling Castle Court
# Spanish Oak => Spanish Oak
# Live Oak => Live Oak
# Five Acre Wood => Five Acre Wood
# Crestmont => Crestmont
# North Mopac Expressway => North Mopac Expressway
# North Mo-Pac Expressway => North Mo-Pac Expressway
# North MoPac Expressway => North MoPac Expressway
# South MoPac Expressway => South MoPac Expressway
# Harrier Flight Trl => Harrier Flight Trail
# Dusty Chisolm Trl => Dusty Chisolm Trail
# Poppy Hills Trl => Poppy Hills Trail
# Scenic Overlook Trl => Scenic Overlook Trail
# Bayswater Garden => Bayswater Garden
# North el Dorado => North el Dorado
# South el Dorado => South el Dorado
# El Dorado => El Dorado
# Bubba's Bluff => Bubba's Bluff
# Crescent Bluff => Crescent Bluff
# Bullick Bluff => Bullick Bluff
# Travis Bluff => Travis Bluff
# Scout Bluff => Scout Bluff
# S Capital of Texas Hwy => South Capital of Texas Highway
# Avenue I => Avenue I
# Thunderbird => Thunderbird
# Sylvan Glade => Sylvan Glade
# Rue de St Raphael => Rue de Street Raphael
# Vista Corta => Vista Corta
# Branding Iron => Branding Iron
# Kyle Crossing => Kyle Crossing
# Roller Crossing => Roller Crossing
# Hidden Lake Crossing => Hidden Lake Crossing
# Colorado Crossing => Colorado Crossing
# Bratton Ridge Crossing => Bratton Ridge Crossing
# Kenter Crossing => Kenter Crossing
# Mackinaw Crossing => Mackinaw Crossing
# Fritz Falls Crossing => Fritz Falls Crossing
# Hammetts Crossing => Hammetts Crossing
# Cloud Mountain Crossing => Cloud Mountain Crossing
# Walnut Park Crossing => Walnut Park Crossing
# Steeds Crossing => Steeds Crossing
# Lady Lauras Crossing => Lady Lauras Crossing
# Mandarin Crossing => Mandarin Crossing
# Kohlers Crossing => Kohlers Crossing
# Dover Ferry Crossing => Dover Ferry Crossing
# Little Deer Crossing => Little Deer Crossing
# West Cave Crossing => West Cave Crossing
# Coaches Crossing => Coaches Crossing
# Campina Crossing => Campina Crossing
# Cherry Hollow Crossing => Cherry Hollow Crossing
# Esperanza Crossing => Esperanza Crossing
# Cliff Crossing => Cliff Crossing
# Hyson Crossing => Hyson Crossing
# Nuckols Crossing => Nuckols Crossing
# Dry Brook Crossing => Dry Brook Crossing
# Surveyors Crossing => Surveyors Crossing
# Brown Juniper => Brown Juniper
# Stillhouse Spring => Stillhouse Spring
# Challenger => Challenger
# Stoneridge Terrace => Stoneridge Terrace
# River Terrace => River Terrace
# Preserve Vista Terrace => Preserve Vista Terrace
# White Rim Terrace => White Rim Terrace
# Kisoba Terrace => Kisoba Terrace
# Tallison Terrace => Tallison Terrace
# Vikki Terrace => Vikki Terrace
# Ledgestone Terrace => Ledgestone Terrace
# Crystal Terrace => Crystal Terrace
# Timarou Terrace => Timarou Terrace
# Theckla Terrace => Theckla Terrace
# Bayridge Terrace => Bayridge Terrace
# Begonia Terrace => Begonia Terrace
# Rosedale Terrace => Rosedale Terrace
# Rockbridge Terrace => Rockbridge Terrace
# Reagan Terrace => Reagan Terrace
# Highland Terrace => Highland Terrace
# Lily Terrace => Lily Terrace
# Carnation Terrace => Carnation Terrace
# Carrizo Terrace => Carrizo Terrace
# Swelfling Terrace => Swelfling Terrace
# Edgecliff Terrace => Edgecliff Terrace
# Niagara Falls Terrace => Niagara Falls Terrace
# Yellowpine Terrace => Yellowpine Terrace
# Arren Terrace => Arren Terrace
# Foothill Terrace => Foothill Terrace
# Norseman Terrace => Norseman Terrace
# Cradlerock Terrace => Cradlerock Terrace
# Larch Terrace => Larch Terrace
# Ski Shores Terrace => Ski Shores Terrace
# Club Terrace => Club Terrace
# Spanish Oak Terrace => Spanish Oak Terrace
# Highland Hills Terrace => Highland Hills Terrace
# Windy Terrace => Windy Terrace
# Eagle Fledge Terrace => Eagle Fledge Terrace
# Star Light Terrace => Star Light Terrace
# Cherry Laurel Terrace => Cherry Laurel Terrace
# Arch Terrace => Arch Terrace
# Ludlow Terrace => Ludlow Terrace
# Westwood Terrace => Westwood Terrace
# Callisto Terrace => Callisto Terrace
# Pinewood Terrace => Pinewood Terrace
# Breeze Terrace => Breeze Terrace
# Trailview Mesa Terrace => Trailview Mesa Terrace
# Algerita Terrace => Algerita Terrace
# Century Oaks Terrace => Century Oaks Terrace
# Teasdale Terrace => Teasdale Terrace
# Greenridge Terrace => Greenridge Terrace
# Lookout Bluff Terrace => Lookout Bluff Terrace
# Tay Terrace => Tay Terrace
# Marigold Terrace => Marigold Terrace
# Sterling Panorama Terrace => Sterling Panorama Terrace
# Shady Oak Terrace => Shady Oak Terrace
# Dunlop Terrace => Dunlop Terrace
# Green Emerald Terrace => Green Emerald Terrace
# Mifflin Kenedy Terrace => Mifflin Kenedy Terrace
# Industrial Terrace => Industrial Terrace
# Highgrove Terrace => Highgrove Terrace
# Gentle Breeze Terrace => Gentle Breeze Terrace
# Ridgetop Terrace => Ridgetop Terrace
# Lakewood Hills Terrace => Lakewood Hills Terrace
# Dark Star Terrace => Dark Star Terrace
# Buckingham Gate Terrace => Buckingham Gate Terrace
# Honey Dew Terrace => Honey Dew Terrace
# Airline Terrace => Airline Terrace
# Box Canyon Terrace => Box Canyon Terrace
# Fargo Terrace => Fargo Terrace
# Eastridge Terrace => Eastridge Terrace
# Bonham Terrace => Bonham Terrace
# Lago Viento => Lago Viento
# Desert Flower => Desert Flower
# Broken Arrow => Broken Arrow
# Greystone Dr Ste 210 => Greystone Drive Ste 210
# Wind Cave => Wind Cave
# Aleppo Pine => Aleppo Pine
# Sierra Madre => Sierra Madre
# Sierra Tahoe => Sierra Tahoe
# Maverick => Maverick
# Buffalo Gap => Buffalo Gap
# Gnu Gap => Gnu Gap
# Encino Verde => Encino Verde
# Cuesta Verde => Cuesta Verde
# Casa Verde => Casa Verde
# 4201 South Congress Avenue #4 => 4201 South Congress Avenue #4
# County Road 280 => County Road 280
# Buckskin => Buckskin
# Criswell => Criswell
# Camino Alto => Camino Alto
# Palo Alto => Palo Alto
# Avenue D => Avenue D
# Channel Island => Channel Island
# Camino Seco => Camino Seco
# Arroyo Seco => Arroyo Seco
# Rio Seco => Rio Seco
# Soter Pkwy => Soter Parkway
# Riata Trace Pkwy => Riata Trace Parkway
# Beverly Skyline => Beverly Skyline
# Hill Country Skyline => Hill Country Skyline
# S Interstate 35, #260 => South Interstate 35, #260
# Laguna Grande => Laguna Grande
# Mesa Grande => Mesa Grande
# Rio Grande => Rio Grande
# Rain Lily Creek => Rain Lily Creek
# Boulder Creek => Boulder Creek
# Canyon Creek => Canyon Creek
# Deep Creek => Deep Creek
# Cross Creek => Cross Creek
# Rock Creek => Rock Creek
# Tealwood => Tealwood
# FM 535 => FM 535
# FM 1327 => FM 1327
# Farm-to-Market Road 1327 => Farm-to-Market Road 1327
# Buffalo Thunder => Buffalo Thunder
# Olympic Overlook => Olympic Overlook
# Bright Sky Overlook => Bright Sky Overlook
# Plum Hollow Overlook => Plum Hollow Overlook
# Cliff Overlook => Cliff Overlook
# Bonanza => Bonanza
# Stonebridge Dr. => Stonebridge Dr
# Sportsplex Dr. => Sportsplex Dr
# Cannon Dr. => Cannon Dr
# 11928 Stonehollow Dr. => 11928 Stonehollow Dr
# Pawnee Pathway => Pawnee Pathway
# Jigsaw Pathway => Jigsaw Pathway
# Happy Vale Pathway => Happy Vale Pathway
# Blackfoot => Blackfoot
# Quarry => Quarry
# Sierra Montana => Sierra Montana
# Greenway => Greenway
# West 5th Street #300 => West 5th Street #300
# 321 W Ben White Blvd #300 => 321 West Ben White Boulevard #300
# S Bell Blvd., Suite 301 => South Bell Blvd., Suite 301
# Hwy 290 W. Ste. 301 => Highway 290 West Ste. 301
# Medio Calle => Medio Calle
# Cane Pace => Cane Pace
# Rambling Range => Rambling Range
# Speaking Rock => Speaking Rock
# Amberwood Loop => Amberwood Loop
# La Plata Loop => La Plata Loop
# Stagecoach Ranch Loop => Stagecoach Ranch Loop
# Horseshoe Loop => Horseshoe Loop
# Masi Loop => Masi Loop
# Rector Loop => Rector Loop
# Knoll Crest Loop => Knoll Crest Loop
# Circletree Loop => Circletree Loop
# Corran Ferry Loop => Corran Ferry Loop
# Outlook Ridge Loop => Outlook Ridge Loop
# Village Oak Loop => Village Oak Loop
# Silent Harbor Loop => Silent Harbor Loop
# Scotia Bluff Loop => Scotia Bluff Loop
# Osprey Ridge Loop => Osprey Ridge Loop
# Anarosa Loop => Anarosa Loop
# Bayton Loop => Bayton Loop
# Village View Loop => Village View Loop
# Fantail Loop => Fantail Loop
# Little Loop => Little Loop
# Candace Loop => Candace Loop
# Saville Loop => Saville Loop
# Sunrise Ridge Loop => Sunrise Ridge Loop
# Kirtomy Loop => Kirtomy Loop
# Lakehurst Loop => Lakehurst Loop
# Franklins Tale Loop => Franklins Tale Loop
# Rowe Loop => Rowe Loop
# Old Post Loop => Old Post Loop
# Mirasol Loop => Mirasol Loop
# Lake Loop => Lake Loop
# Double Spur Loop => Double Spur Loop
# E. North Loop => East North Loop
# Janet Loop => Janet Loop
# Staked Plains Loop => Staked Plains Loop
# Twin Lake Loop => Twin Lake Loop
# Whitebrush Loop => Whitebrush Loop
# Barrow Glen Loop => Barrow Glen Loop
# Ponciana Loop => Ponciana Loop
# West Loop => West Loop
# Spillman Ranch Loop => Spillman Ranch Loop
# Layne Loop => Layne Loop
# Donna Jane Loop => Donna Jane Loop
# Cameron Loop => Cameron Loop
# Magna Carta Loop => Magna Carta Loop
# Hansa Loop => Hansa Loop
# Walsall Loop => Walsall Loop
# West Pflugerville Loop => West Pflugerville Loop
# Witsome Loop => Witsome Loop
# Lily Lake Loop => Lily Lake Loop
# Gerald Allen Loop => Gerald Allen Loop
# Cardinal Loop => Cardinal Loop
# Dry Brook Loop => Dry Brook Loop
# Wayne Riddell Loop => Wayne Riddell Loop
# Leanna Oaks Loop => Leanna Oaks Loop
# Briarcreek Loop => Briarcreek Loop
# Post Oak Bend Loop => Post Oak Bend Loop
# Crane Creek Loop => Crane Creek Loop
# Ridgeview Loop => Ridgeview Loop
# Seneca Falls Loop => Seneca Falls Loop
# Foothill Farms Loop => Foothill Farms Loop
# Travis View Loop => Travis View Loop
# Wingreen Loop => Wingreen Loop
# Loch Linnhe Loop => Loch Linnhe Loop
# Panther Loop => Panther Loop
# West Hove Loop => West Hove Loop
# Christoff Loop => Christoff Loop
# Lightwood Loop => Lightwood Loop
# Cherry Loop => Cherry Loop
# Windy Shores Loop => Windy Shores Loop
# Lanna Bluff Loop => Lanna Bluff Loop
# Bastogne Loop => Bastogne Loop
# Olympia Fields Loop => Olympia Fields Loop
# Lanark Loop => Lanark Loop
# Celery Loop => Celery Loop
# Lockleven Loop => Lockleven Loop
# Lipton Loop => Lipton Loop
# Whiteworth Loop => Whiteworth Loop
# Wild Canyon Loop => Wild Canyon Loop
# Linden Loop => Linden Loop
# Bronco Bend Loop => Bronco Bend Loop
# Calhoun Canyon Loop => Calhoun Canyon Loop
# Colonel Winn Loop => Colonel Winn Loop
# Austral Loop => Austral Loop
# Maravillas Loop => Maravillas Loop
# Croydon Loop => Croydon Loop
# Marble Creek Loop => Marble Creek Loop
# Grand Oaks Loop => Grand Oaks Loop
# East Hove Loop => East Hove Loop
# Highland Lake Loop => Highland Lake Loop
# Long Hollow Loop => Long Hollow Loop
# Hudson Loop => Hudson Loop
# Rennalee Loop => Rennalee Loop
# Sage Creek Loop => Sage Creek Loop
# Independence Loop => Independence Loop
# Rising Smoke Loop => Rising Smoke Loop
# Vizquel Loop => Vizquel Loop
# Desert Willow Loop => Desert Willow Loop
# Whitt Loop => Whitt Loop
# Levander Loop => Levander Loop
# Indigo Broom Loop => Indigo Broom Loop
# Lindeman Loop => Lindeman Loop
# Springs Head Loop => Springs Head Loop
# West Cave Loop => West Cave Loop
# Pusch Ridge Loop => Pusch Ridge Loop
# Big Boggy => Big Boggy
# Regal Row => Regal Row
# Governors Row => Governors Row
# Fence Row => Fence Row
# Henry Kinney Row => Henry Kinney Row
# College Row => College Row
# Kings Row => Kings Row
# Warehouse Row => Warehouse Row
# Fuzz Fairway => Fuzz Fairway
# Lajitas => Lajitas
# Rue de St Germaine => Rue de Street Germaine
# Meadow Crest => Meadow Crest
# FM1431 => FM1431
# Pheasant Roost => Pheasant Roost
# Julian Alps => Julian Alps
# Sutton => Sutton
# Firebird => Firebird
# Business Interstate Highway 35 J => Business Interstate Highway 35 J
# Caisteal Castle => Caisteal Castle
# Research Blvd, Austin => Research Blvd, Austin
# FM 3177 => FM 3177
# Turnback => Turnback
# Sierra Leon => Sierra Leon
# Melanie's Walk => Melanie's Walk
# Fairfax Walk => Fairfax Walk
# Winding Walk => Winding Walk
# Gillians Walk => Gillians Walk
# Whitemarsh Valley Walk => Whitemarsh Valley Walk
# Midland Walk => Midland Walk
# Julies Walk => Julies Walk
# Village Walk => Village Walk
# Liberty Walk => Liberty Walk
# Regents Walk => Regents Walk
# Round Rock Ave => Round Rock Avenue
# Barstow Ave => Barstow Avenue
# South Congress Ave => South Congress Avenue
# E. University Ave => East University Avenue
# S Congress Ave => South Congress Avenue
# House of Lancaster => House of Lancaster
# Farm-to-Market Road 150 => Farm-to-Market Road 150
# Buena Vista => Buena Vista
# Twilight Vista => Twilight Vista
# Mira Vista => Mira Vista
# Agua Vista => Agua Vista
# Puerta Vista => Puerta Vista
# Verde Vista => Verde Vista
# Burnet Road #600 => Burnet Road #600
# Amaryllis Tr => Amaryllis Trail
# Posse Tr => Posse Trail
# Sunflower Tr => Sunflower Trail
# Blackeyed Susan Tr => Blackeyed Susan Trail
# Wood Lily Tr => Wood Lily Trail
# Date Palm Tr => Date Palm Trail
# Sycamore Tr => Sycamore Trail
# Maidenhair Tr => Maidenhair Trail
# Plaza on the Lake => Plaza on the Lake
# Buffalo Lake => Buffalo Lake
# Crater Lake => Crater Lake
# Circulo de Amistad => Circulo de Amistad
# Southview => Southview
# Loma Linda => Loma Linda
# Casitas => Casitas
# Camino Real => Camino Real
# Una Mas => Una Mas
# State Highway 71 W Spicewood => State Highway 71 West Spicewood
# Hampton Bliss Trace => Hampton Bliss Trace
# Tall Sky Trace => Tall Sky Trace
# Mill Ridge Trace => Mill Ridge Trace
# Juniper Trace => Juniper Trace
# Outpost Trace => Outpost Trace
# Dayflower Trace => Dayflower Trace
# Shadowglen Trace => Shadowglen Trace
# Tercel Trace => Tercel Trace
# Hunters Trace => Hunters Trace
# Single Trace => Single Trace
# Shadowlawn Trace => Shadowlawn Trace
# Flintrock Trace => Flintrock Trace
# Deer Track => Deer Track
# TX 45 => TX 45
# Greenwich Meridian => Greenwich Meridian
# Atlantic => Atlantic
# La Costa => La Costa
# Camino La Costa => Camino La Costa
# I-35 Frontage => I-35 Frontage
# Elysian Fields => Elysian Fields
# devonshire cove => devonshire Cove
# Hidden Estates => Hidden Estates
# Pecan St => Pecan Street
# N Main St => North Main Street
# S 1st St => South 1st Street
# E Oltorf St => East Oltorf Street
# E 43rd St => East 43rd Street
# Red River St => Red River Street
# Yoakum St => Yoakum Street
# W 10th St => West 10th Street
# W Annie St => West Annie Street
# Chinese Elm St => Chinese Elm Street
# Rio Grande St => Rio Grande Street
# W 6th St => West 6th Street
# West Lynn St => West Lynn Street
# Guadalupe St => Guadalupe Street
# Kendalia St => Kendalia Street
# Duval St => Duval Street
# Comanche => Comanche
# brigadoon lane => brigadoon Lane
# Victory Gallop => Victory Gallop
# Pawnee => Pawnee
# Scott Crescent => Scott Crescent
# Margranita Crescent => Margranita Crescent
# Canyon Maple => Canyon Maple
# Sunfish => Sunfish

# %%
#auditing postcode data

#regex to ID if there are letters in the postcode
postcode_letter_re = re.compile('[a-zA-Z]')

#open the osm fie, iterate by events, find postcode elem
#if appropriate attribute is a postcode then check to see if either:
#the post code contains letters or if the post code is longer than 5 characters
#if either condition is true, add it to a postcode_types set and return the set
def audit(osmfile):
    osm_file = open(osmfile, "r")
    postcode_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if tag.attrib['k'] == 'addr:postcode':
                    m = postcode_letter_re.search(tag.attrib['v'])
                    if m:
                        postcode_type = m.group()
                        postcode_types[postcode_type].add(tag.attrib['v'])
                    elif len(tag.attrib['v']) > 5:
                        postcode_types[len(tag.attrib['v'])].add(tag.attrib['v'])
    
    return postcode_types


#take the offending code, split it, ID if letters need to be truncated from front
#or if the +4 needs to be stripped from back
#if there is only text in the zip field, return None
#return only the 5 digit zip
def update_code(code):

    split_code = re.split(' |-',code)
    if len(split_code) > 1:
        m = postcode_letter_re.search(split_code[0])
        if m:
            code = split_code[1]
        if len(split_code[-1]) < 5:
            if len(split_code) > 2:
                code = split_code[1]
            elif len(split_code) < 3:
                code = split_code[0]
    else:
        if postcode_letter_re.search(split_code[0]):
            code = None    
    return code

#testing the code and as with the street names, show original and bettered versions
if __name__ == '__main__':
    pc_types = audit(atx_osm)
    for pc_type, ways in pc_types.iteritems():
        for code in ways:
            better_code = update_code(code)
            print code , "=>", better_code
# Out:
# 78640-4520 => 78640
# 76574-4649 => 76574
# 78754-5701 => 78754
# 78724-1199 => 78724
# 78704-7205 => 78704
# 78758-7008 => 78758
# 78728-1275 => 78728
# 78753-4150 => 78753
# 78758-7013 => 78758
# 78640-6137 => 78640
# 78704-5639 => 78704
# TX 78745 => 78745
# TX 78758 => 78758
# TX 78735 => 78735
# TX 78613 => 78613
# TX 78759-3504 => 78759
# TX 78724 => 78724
# TX 78728 => 78728
# Texas => None
# tx => None

# %%
#what other data to audit? let's see if phones have differing standards...
#yep, they sure do!


#auditing postcode data

#check if the phone number has text
phone_letter_re = re.compile('[a-zA-Z]')

#as with the postcode audit... open osm, iterate event-wise, find phone elem,
#if phone has letters or if phone is essentially not blank, add this to phone_types set
#and return the set
def audit(osmfile):
    osm_file = open(osmfile, "r")
    phone_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if tag.attrib['k'] == 'phone':                    
                    m = phone_letter_re.search(tag.attrib['v'])
                    if m:
                        phone_type = m.group()
                        phone_types[phone_type].add(tag.attrib['v'])
                    elif len(tag.attrib['v']) > 0:
                        phone_types[tag.attrib['v']].add(tag.attrib['v'])
    
    return phone_types


#helper function that formats the phone number
#takes a phone number split by digit, assembles into basic
#pieces: country code, area code, first 3 and last 4
#then it returns the assemble list of length 4
def assemble_number(data):
    assemble = []
    assemble.append(data[0])
    assemble.append("".join(data[1:4]))
    assemble.append("".join(data[4:7]))
    assemble.append("".join(data[7:]))
    return assemble
    
    
#update previously unstandardized phone numbers into a single standard form    
def update_code(code):
    #turn the original phone number into a list after stripping any excess chars
    clean_code = code.strip()
    split_code = list(clean_code)
    
    #walk through each char in the phone number and only spit out the digits
    new = [x for x in split_code if x.isdigit()]
    
    #if the first number does not have a '1' as a country code, insert it
    if new[0] != '1':
        new.insert(0,'1')
    
    #if the list has a length greater than the length of the standard phone number,
    #split it into two numbers
    if len(new) > 11:
        first = new[:11]
        second = new[11:]
        
        #but if the second number is less than the standard phone number excluding a country code
        #return None as we don't know if there was a misstype in the original number that led it
        #to be longer than 11 digits
        if len(second) < 10:
            return None
        
        #if the second number doesn't have a country code, add it
        if second[0] != '1':
            second.insert(0,'1')
        both_list = [first, second]
        both = []
        
        #iterate through the list of phone numbers and use the assemble function to structure the 4 phone elems
        #join the new list on '-' so that it fits a X-XXX-XXX-XXXX standard and return both numbers as a list
        for order in both_list:
            phone = "-".join(assemble_number(order))
            both.append(phone)
        return both
    
    #if we just had one number rather than two and it was the appropriate length,
    #call the assemble function to structure the number and join on the '-'
    phone = "-".join(assemble_number(new))
    
    return phone
    
#as with postcodes, print the offending number and its bettered self
if __name__ == '__main__':
    phone_types = audit(atx_osm)
    for phone_type, ways in phone_types.iteritems():
        for phone in ways:
            better_code = update_code(phone)
            print phone , "=>", better_code
# 512-472-2783 => 1-512-472-2783
# 512-476-6182 => 1-512-476-6182
# (512) 263-0528 => 1-512-263-0528
# (512) 858-2972 => 1-512-858-2972
# +1-512-821-9472 => 1-512-821-9472
# +1--512-452-2518 => 1-512-452-2518
# (512) 899-3473 => 1-512-899-3473
# 512-318-2500 => 1-512-318-2500
# 512-478-5684 => 1-512-478-5684
# +1 (512) 469-7000 => 1-512-469-7000
# +1 512 243 5847 => 1-512-243-5847
# (512) 477-2676 => 1-512-477-2676
# 512.476.4596 => 1-512-476-4596
# +1 512 295 1670 => 1-512-295-1670
# (512) 268-7955 => 1-512-268-7955
# (512) 238-7905 => 1-512-238-7905
# (512) 249-0558 => 1-512-249-0558
# +1-512-372-8771 => 1-512-372-8771
# 512-345-3771 => 1-512-345-3771
# +1 512 652 4800 => 1-512-652-4800
# 512 466-3937 => 1-512-466-3937
# +1 512 472-5718 => 1-512-472-5718
# +1 512 480 8441 => 1-512-480-8441
# 512-478-9387 => 1-512-478-9387
# (512) 236-1219 => 1-512-236-1219
# 512-379-7272 => 1-512-379-7272
# 1-512-986-7038 => 1-512-986-7038
# 512-234-1868 => 1-512-234-1868
# (512) 892-6699 => 1-512-892-6699
# 512-891-4360 => 1-512-891-4360
# +1 512 353 2832 => 1-512-353-2832
# (512) 321-1011 => 1-512-321-1011
# +1-512-309-1044 => 1-512-309-1044
# +1-512-961-3680 => 1-512-961-3680
# (512) 312-1615 => 1-512-312-1615
# (512) 858-2400 => 1-512-858-2400
# +1 512 246 9800 => 1-512-246-9800
# 512-453-8434 => 1-512-453-8434
# (512) 433-6762 => 1-512-433-6762
# +1 512-297-2051 => 1-512-297-2051
# +1 512 454 3664 => 1-512-454-3664
# (512) 502-8801 => 1-512-502-8801
# 512-462-5353 => 1-512-462-5353
# +1 512 295 8166 => 1-512-295-8166
# (512)320-0553 => 1-512-320-0553

# %% [markdown]
# ### Ok we are done with 3 ways to clean this particular dataset, let's do it for real this time

# %%
#using the structure of quiz 6.5 to form the shape of the json doc

import codecs
import json

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

def shape_element(element):
    
    node = {}
    address = {}
    pos=[]
    node['pos'] = pos
    
    #only looking at node and way tags
    if element.tag == "node" or element.tag == "way" :
        node['id'] = element.attrib['id']
        node['type'] = element.tag
        if 'visible' in element.attrib:
            node['visible'] = element.attrib['visible']
       
        created = {}
        for i in CREATED:
            created[i]=element.attrib[i]  
            node['created']=created
        
        #now let's dig through elements
        for elem in element:
            if 'k' in elem.attrib:  #if there is a key attribute...
                if elem.attrib['k'].count(':')<2:  #and if that key attribute does not contain more than 1 ':'...
                    if elem.attrib['k'].startswith("addr:"): #and if it starts with 'addr:'...
                        stripped=elem.attrib['k'].replace("addr:","")  #remove 'addr:' and take what remains
                        if stripped == 'housenumber':  #if what remains is 'housenumber', store that
                            address['housenumber'] = elem.attrib['v'] 
                        if stripped == 'street': #if what remains is street...
                            m = street_type_re.search(elem.attrib['v']) #run the regex matching function
                            if m:  #if the street is not appropriately formatted...
                                address['street'] = update_name(elem.attrib['v'], mapping) #run the update function from above
                            else: #otherwise just set the street name as is
                                address['street'] = elem.attrib['v']
                        if stripped == 'postcode': #if what remains is postcode...
                            code = elem.attrib['v'] #take the postcode...
                            split_code = re.split(' |-',code) #split it on whitespace and dash...
                            if len(split_code) > 1: #if the code is longer than 1...
                                m = postcode_letter_re.search(split_code[0]) #run the regex matching function
                                if m: #if there is a match...
                                    code = split_code[1] #take the second item in the split postcode and store it
                                if len(split_code[-1]) < 5: #if the last item in split_code is less than 5 (i.e. it's the +4)...
                                    if len(split_code) > 2: #and if the split_code list is more than 2 items..
                                        code = split_code[1]#store the second item in split_code
                                    elif len(split_code) < 3:#but if the split_code list is 2 or 1 item long...
                                        code = split_code[0] #store the first item in split_code     
                            else: #but if split_code is only one item long...
                                if postcode_letter_re.search(split_code[0]): #and there is a match!
                                    code = None #code becomes None (likely text rather than numbers in the zip field)
                            address['postcode'] = code
                        node['address'] = address    #load the address dictionary into 'address'
                    else:
                        node[elem.attrib['k']]=elem.attrib['v']

        
        
        #run through some try/except statements in case some fields are missing in the dataset
        try:
            node["amenity"]=element.attrib['amenity']
        except :
            pass
        try:
            node["cuisine"]=element.attrib['cuisine']
        except :
            pass        
        try:
            node["name"]=element.attrib['name']
        except :
            pass
        try:
            #here we standardize the phone attribute
            
            #take the initial phone number...
            #and run a modified form of the update function from above
            
            #key differences are that the return statements from the update function are now
            #replaced with a slightly different if/elif/else structure
            
            code = element.attrib['phone']
            clean_code = code.strip()  #strip it...
            split_code = list(clean_code)#turn it into a list...
            new = [x for x in split_code if x.isdigit()]#and turn that list into a char by char list composed of only digits
            if new[0] != '1':
                new.insert(0,'1')
            if len(new) > 11:
                first = new[:11]
                second = new[11:]
                if len(second) < 10:
                    node["phone"] = None
                elif second[0] != '1':
                    second.insert(0,'1')
                    both_list = [first, second]
                    both = []
        
                    for order in both_list:
                        phone = "-".join(assemble_number(order))
                        both.append(phone)
                    node["phone"] = both
    
            else:
                phone = "-".join(assemble_number(new))
                node["phone"] = phone
        except :
            pass 
        try:
            node['pos'].append(float(element.attrib['lat']))
            node['pos'].append(float(element.attrib['lon']))             
        except : 
            pass
                                                           
        #print node
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map(atx_osm, False)
    #pprint.pprint(data)
    

if __name__ == "__main__":
    test()

# %% [markdown]
# ### Now I have a json file... ho, ho, ho
# ###### (rip Alan Rickman)

# %%
#loading json into mongodb instance

import json

if __name__ == "__main__":
    
    from pymongo import MongoClient
    client = MongoClient()
    db = client.atx

    with open(DATA_DIR + '/austin_texas.osm.json') as f:
        data = []
        for line in f:
            data.append(json.loads(line))

# %%
#insert the data into the instance
db.atx.insert(data)
# Out:
# /Users/patrickkennedy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':
# [ObjectId('569dc100c8ac4e03274ae65e'),
#  ObjectId('569dc100c8ac4e03274ae65f'),
#  ObjectId('569dc100c8ac4e03274ae660'),
#  ObjectId('569dc100c8ac4e03274ae661'),
#  ObjectId('569dc100c8ac4e03274ae662'),
#  ObjectId('569dc100c8ac4e03274ae663'),
#  ObjectId('569dc100c8ac4e03274ae664'),
#  ObjectId('569dc100c8ac4e03274ae70e'),
#  ObjectId('569dc100c8ac4e03274ae70f'),
#  ObjectId('569dc100c8ac4e03274ae710'),
#  ObjectId('569dc100c8ac4e03274ae711'),
#  ObjectId('569dc100c8ac4e03274ae712'),
#  ObjectId('569dc100c8ac4e03274ae713'),
#  ObjectId('569dc100c8ac4e03274ae714'),
#  ObjectId('569dc100c8ac4e03274ae715'),
#  ObjectId('569dc100c8ac4e03274ae716'),
#  ObjectId('569dc100c8ac4e03274ae717'),
#  ObjectId('569dc100c8ac4e03274ae718'),
#  ObjectId('569dc100c8ac4e03274ae719'),
#  ObjectId('569dc100c8ac4e03274ae71a'),
#  ObjectId('569dc100c8ac4e03274ae71b'),
#  ObjectId('569dc100c8ac4e03274ae71c'),
#  ObjectId('569dc100c8ac4e03274ae71d'),
#  ObjectId('569dc100c8ac4e03274ae71e'),
#  ObjectId('569dc100c8ac4e03274ae71f'),
#  ObjectId('569dc100c8ac4e03274ae720'),
#  ObjectId('569dc100c8ac4e03274ae721'),
#  ObjectId('569dc100c8ac4e03274ae722'),
#  ObjectId('569dc100c8ac4e03274ae723'),
#  ObjectId('569dc100c8ac4e03274ae724'),
#  ObjectId('569dc100c8ac4e03274ae725'),
#  ObjectId('569dc100c8ac4e03274ae726'),
#  ObjectId('569dc100c8ac4e03274ae727'),
#  ObjectId('569dc100c8ac4e03274ae728'),
#  ObjectId('569dc100c8ac4e03274ae729'),
#  ObjectId('569dc100c8ac4e03274ae72a'),
#  ObjectId('569dc100c8ac4e03274ae72b'),
#  ObjectId('569dc100c8ac4e03274ae72c'),
#  ObjectId('569dc100c8ac4e03274ae72d'),
#  ObjectId('569dc100c8ac4e03274ae72e'),
#  ObjectId('569dc100c8ac4e03274ae72f'),
#  ObjectId('569dc100c8ac4e03274ae730'),
#  ObjectId('569dc100c8ac4e03274ae731'),
#  ObjectId('569dc100c8ac4e03274ae732'),
#  ObjectId('569dc100c8ac4e03274ae733'),
#  ObjectId('569dc100c8ac4e03274ae734'),
#  ObjectId('569dc100c8ac4e03274ae735'),
#  ObjectId('569dc100c8ac4e03274ae736'),
#  ObjectId('569dc100c8ac4e03274ae737'),
#  ObjectId('569dc100c8ac4e03274ae738'),
#  ObjectId('569dc100c8ac4e03274ae739'),
#  ObjectId('569dc100c8ac4e03274ae73a'),
#  ObjectId('569dc100c8ac4e03274ae73b'),
#  ObjectId('569dc100c8ac4e03274ae73c'),
#  ObjectId('569dc100c8ac4e03274ae73d'),
#  ObjectId('569dc100c8ac4e03274ae73e'),
#  ObjectId('569dc100c8ac4e03274ae73f'),
#  ObjectId('569dc100c8ac4e03274ae740'),
#  ObjectId('569dc100c8ac4e03274ae741'),
#  ObjectId('569dc100c8ac4e03274ae742'),
#  ObjectId('569dc100c8ac4e03274ae743'),
#  ObjectId('569dc100c8ac4e03274ae744'),
#  ObjectId('569dc100c8ac4e03274ae745'),
#  ObjectId('569dc100c8ac4e03274ae746'),
#  ObjectId('569dc100c8ac4e03274ae747'),
#  ObjectId('569dc100c8ac4e03274ae782'),
#  ObjectId('569dc100c8ac4e03274ae783'),
#  ObjectId('569dc100c8ac4e03274ae784'),
#  ObjectId('569dc100c8ac4e03274ae785'),
#  ObjectId('569dc100c8ac4e03274ae786'),
#  ObjectId('569dc100c8ac4e03274ae787'),
#  ObjectId('569dc100c8ac4e03274ae788'),
#  ObjectId('569dc100c8ac4e03274ae789'),
#  ObjectId('569dc100c8ac4e03274ae78a'),
#  ObjectId('569dc100c8ac4e03274ae78b'),
#  ObjectId('569dc100c8ac4e03274ae78c'),
#  ObjectId('569dc100c8ac4e03274ae78d'),
#  ObjectId('569dc100c8ac4e03274ae78e'),
#  ObjectId('569dc100c8ac4e03274ae78f'),
#  ObjectId('569dc100c8ac4e03274ae790'),
#  ObjectId('569dc100c8ac4e03274ae791'),
#  ObjectId('569dc100c8ac4e03274ae792'),
#  ObjectId('569dc100c8ac4e03274ae793'),
#  ObjectId('569dc100c8ac4e03274ae794'),
#  ObjectId('569dc100c8ac4e03274ae795'),
#  ObjectId('569dc100c8ac4e03274ae796'),
#  ObjectId('569dc100c8ac4e03274ae797'),
#  ObjectId('569dc100c8ac4e03274ae798'),
#  ObjectId('569dc100c8ac4e03274ae799'),
#  ObjectId('569dc100c8ac4e03274ae79a'),
#  ObjectId('569dc100c8ac4e03274ae79b'),
#  ObjectId('569dc100c8ac4e03274ae79c'),
#  ObjectId('569dc100c8ac4e03274ae79d'),
#  ObjectId('569dc100c8ac4e03274ae79e'),
#  ObjectId('569dc100c8ac4e03274ae79f'),
#  ObjectId('569dc100c8ac4e03274ae7a0'),
#  ObjectId('569dc100c8ac4e03274ae7a1'),
#  ObjectId('569dc100c8ac4e03274ae7a2'),
#  ObjectId('569dc100c8ac4e03274ae7a3'),
#  ObjectId('569dc100c8ac4e03274ae7a4'),
#  ObjectId('569dc100c8ac4e03274ae7a5'),
#  ObjectId('569dc100c8ac4e03274ae7a6'),
#  ObjectId('569dc100c8ac4e03274ae7a7'),
#  ObjectId('569dc100c8ac4e03274ae7a8'),
#  ObjectId('569dc100c8ac4e03274ae7a9'),
#  ObjectId('569dc100c8ac4e03274ae7aa'),
#  ObjectId('569dc100c8ac4e03274ae7ab'),
#  ObjectId('569dc100c8ac4e03274ae7ac'),
#  ObjectId('569dc100c8ac4e03274ae7ad'),
#  ObjectId('569dc100c8ac4e03274ae7ae'),
#  ObjectId('569dc100c8ac4e03274ae7af'),
#  ObjectId('569dc100c8ac4e03274ae7b0'),
#  ObjectId('569dc100c8ac4e03274ae7b1'),
#  ObjectId('569dc100c8ac4e03274ae7b2'),
#  ObjectId('569dc100c8ac4e03274ae7b3'),
#  ObjectId('569dc100c8ac4e03274ae7b4'),
#  ObjectId('569dc100c8ac4e03274ae7b5'),
#  ObjectId('569dc100c8ac4e03274ae7b6'),
#  ObjectId('569dc100c8ac4e03274ae7b7'),
#  ObjectId('569dc100c8ac4e03274ae7b8'),
#  ObjectId('569dc100c8ac4e03274ae7b9'),
#  ObjectId('569dc100c8ac4e03274ae7ba'),
#  ObjectId('569dc100c8ac4e03274ae7bb'),
#  ObjectId('569dc100c8ac4e03274ae7bc'),
#  ObjectId('569dc100c8ac4e03274ae7bd'),
#  ObjectId('569dc100c8ac4e03274ae7be'),
#  ObjectId('569dc100c8ac4e03274ae7bf'),
#  ObjectId('569dc100c8ac4e03274ae7c0'),
#  ObjectId('569dc100c8ac4e03274ae7c1'),
#  ObjectId('569dc100c8ac4e03274ae7c2'),
#  ObjectId('569dc100c8ac4e03274ae7c3'),
#  ObjectId('569dc100c8ac4e03274ae7c4'),
#  ObjectId('569dc100c8ac4e03274ae7c5'),
#  ObjectId('569dc100c8ac4e03274ae7c6'),
#  ObjectId('569dc100c8ac4e03274ae7c7'),
#  ObjectId('569dc100c8ac4e03274ae7c8'),
#  ObjectId('569dc100c8ac4e03274ae7c9'),
#  ObjectId('569dc100c8ac4e03274ae7ca'),
#  ObjectId('569dc100c8ac4e03274ae7cb'),
#  ObjectId('569dc100c8ac4e03274ae7cc'),
#  ObjectId('569dc100c8ac4e03274ae7cd'),
#  ObjectId('569dc100c8ac4e03274ae7ce'),
#  ObjectId('569dc100c8ac4e03274ae7cf'),
#  ObjectId('569dc100c8ac4e03274ae7d0'),
#  ObjectId('569dc100c8ac4e03274ae7d1'),
#  ObjectId('569dc100c8ac4e03274ae7d2'),
#  ObjectId('569dc100c8ac4e03274ae7d3'),
#  ObjectId('569dc100c8ac4e03274ae7d4'),
#  ObjectId('569dc100c8ac4e03274ae7d5'),
#  ObjectId('569dc100c8ac4e03274ae7d6'),
#  ObjectId('569dc100c8ac4e03274ae7d7'),
#  ObjectId('569dc100c8ac4e03274ae7d8'),
#  ObjectId('569dc100c8ac4e03274ae7d9'),
#  ObjectId('569dc100c8ac4e03274ae7da'),
#  ObjectId('569dc100c8ac4e03274ae7db'),
#  ObjectId('569dc100c8ac4e03274ae7dc'),
#  ObjectId('569dc100c8ac4e03274ae7dd'),
#  ObjectId('569dc100c8ac4e03274ae7de'),
#  ObjectId('569dc100c8ac4e03274ae7df'),
#  ObjectId('569dc100c8ac4e03274ae7e0'),
#  ObjectId('569dc100c8ac4e03274ae7e1'),
#  ObjectId('569dc100c8ac4e03274ae7e2'),
#  ObjectId('569dc100c8ac4e03274ae7e3'),
#  ObjectId('569dc100c8ac4e03274ae7e4'),
#  ObjectId('569dc100c8ac4e03274ae7e5'),
#  ObjectId('569dc100c8ac4e03274ae7e6'),
#  ObjectId('569dc100c8ac4e03274ae7e7'),
#  ObjectId('569dc100c8ac4e03274ae7e8'),
#  ObjectId('569dc100c8ac4e03274ae7e9'),
#  ObjectId('569dc100c8ac4e03274ae7ea'),
#  ObjectId('569dc100c8ac4e03274ae7eb'),
#  ObjectId('569dc100c8ac4e03274ae7ec'),
#  ObjectId('569dc100c8ac4e03274ae7ed'),
#  ObjectId('569dc100c8ac4e03274ae7ee'),
#  ObjectId('569dc100c8ac4e03274ae7ef'),
#  ObjectId('569dc100c8ac4e03274ae7f0'),
#  ObjectId('569dc100c8ac4e03274ae7f1'),
#  ObjectId('569dc100c8ac4e03274ae7f2'),
#  ObjectId('569dc100c8ac4e03274ae7f3'),
#  ObjectId('569dc100c8ac4e03274ae7f4'),
#  ObjectId('569dc100c8ac4e03274ae7f5'),
#  ObjectId('569dc100c8ac4e03274ae7f6'),
#  ObjectId('569dc100c8ac4e03274ae7f7'),
#  ObjectId('569dc100c8ac4e03274ae7f8'),
#  ObjectId('569dc100c8ac4e03274ae7f9'),
#  ObjectId('569dc100c8ac4e03274ae7fa'),
#  ObjectId('569dc100c8ac4e03274ae7fb'),
#  ObjectId('569dc100c8ac4e03274ae7fc'),
#  ObjectId('569dc100c8ac4e03274ae7fd'),
#  ObjectId('569dc100c8ac4e03274ae7fe'),
#  ObjectId('569dc100c8ac4e03274ae7ff'),
#  ObjectId('569dc100c8ac4e03274ae800'),
#  ObjectId('569dc100c8ac4e03274ae801'),
#  ObjectId('569dc100c8ac4e03274ae802'),
#  ObjectId('569dc100c8ac4e03274ae803'),
#  ObjectId('569dc100c8ac4e03274ae804'),
#  ObjectId('569dc100c8ac4e03274ae805'),
#  ObjectId('569dc100c8ac4e03274ae806'),
#  ObjectId('569dc100c8ac4e03274ae807'),
#  ObjectId('569dc100c8ac4e03274ae808'),
#  ObjectId('569dc100c8ac4e03274ae809'),
#  ObjectId('569dc100c8ac4e03274ae80a'),
#  ObjectId('569dc100c8ac4e03274ae80b'),
#  ObjectId('569dc100c8ac4e03274ae80c'),
#  ObjectId('569dc100c8ac4e03274ae80d'),
#  ObjectId('569dc100c8ac4e03274ae80e'),
#  ObjectId('569dc100c8ac4e03274ae80f'),
#  ObjectId('569dc100c8ac4e03274ae810'),
#  ObjectId('569dc100c8ac4e03274ae811'),
#  ObjectId('569dc100c8ac4e03274ae812'),
#  ObjectId('569dc100c8ac4e03274ae813'),
#  ObjectId('569dc100c8ac4e03274ae814'),
#  ObjectId('569dc100c8ac4e03274ae815'),
#  ObjectId('569dc100c8ac4e03274ae816'),
#  ObjectId('569dc100c8ac4e03274ae817'),
#  ObjectId('569dc100c8ac4e03274ae818'),
#  ObjectId('569dc100c8ac4e03274ae819'),
#  ObjectId('569dc100c8ac4e03274ae81a'),
#  ObjectId('569dc100c8ac4e03274ae81b'),
#  ObjectId('569dc100c8ac4e03274ae81c'),
#  ObjectId('569dc100c8ac4e03274ae81d'),
#  ObjectId('569dc100c8ac4e03274ae81e'),
#  ObjectId('569dc100c8ac4e03274ae81f'),
#  ObjectId('569dc100c8ac4e03274ae820'),
#  ObjectId('569dc100c8ac4e03274ae821'),
#  ObjectId('569dc100c8ac4e03274ae822'),
#  ObjectId('569dc100c8ac4e03274ae823'),
#  ObjectId('569dc100c8ac4e03274ae824'),
#  ObjectId('569dc100c8ac4e03274ae825'),
#  ObjectId('569dc100c8ac4e03274ae826'),
#  ObjectId('569dc100c8ac4e03274ae827'),
#  ObjectId('569dc100c8ac4e03274ae828'),
#  ObjectId('569dc100c8ac4e03274ae829'),
#  ObjectId('569dc100c8ac4e03274ae82a'),
#  ObjectId('569dc100c8ac4e03274ae82b'),
#  ObjectId('569dc100c8ac4e03274ae82c'),
#  ObjectId('569dc100c8ac4e03274ae82d'),
#  ObjectId('569dc100c8ac4e03274ae82e'),
#  ObjectId('569dc100c8ac4e03274ae82f'),
#  ObjectId('569dc100c8ac4e03274ae830'),
#  ObjectId('569dc100c8ac4e03274ae831'),
#  ObjectId('569dc100c8ac4e03274ae832'),
#  ObjectId('569dc100c8ac4e03274ae833'),
#  ObjectId('569dc100c8ac4e03274ae834'),
#  ObjectId('569dc100c8ac4e03274ae835'),
#  ObjectId('569dc100c8ac4e03274ae836'),
#  ObjectId('569dc100c8ac4e03274ae837'),
#  ObjectId('569dc100c8ac4e03274ae838'),
#  ObjectId('569dc100c8ac4e03274ae839'),
#  ObjectId('569dc100c8ac4e03274ae83a'),
#  ObjectId('569dc100c8ac4e03274ae83b'),
#  ObjectId('569dc100c8ac4e03274ae83c'),
#  ObjectId('569dc100c8ac4e03274ae83d'),
#  ObjectId('569dc100c8ac4e03274ae83e'),
#  ObjectId('569dc100c8ac4e03274ae83f'),
#  ObjectId('569dc100c8ac4e03274ae840'),
#  ObjectId('569dc100c8ac4e03274ae841'),
#  ObjectId('569dc100c8ac4e03274ae842'),
#  ObjectId('569dc100c8ac4e03274ae843'),
#  ObjectId('569dc100c8ac4e03274ae844'),
#  ObjectId('569dc100c8ac4e03274ae845'),
#  ObjectId('569dc100c8ac4e03274ae846'),
#  ObjectId('569dc100c8ac4e03274ae847'),
#  ObjectId('569dc100c8ac4e03274ae848'),
#  ObjectId('569dc100c8ac4e03274ae849'),
#  ObjectId('569dc100c8ac4e03274ae84a'),
#  ObjectId('569dc100c8ac4e03274ae84b'),
#  ObjectId('569dc100c8ac4e03274ae84c'),
#  ObjectId('569dc100c8ac4e03274ae84d'),
#  ObjectId('569dc100c8ac4e03274ae84e'),
#  ObjectId('569dc100c8ac4e03274ae84f'),
#  ObjectId('569dc100c8ac4e03274ae850'),
#  ObjectId('569dc100c8ac4e03274ae851'),
#  ObjectId('569dc100c8ac4e03274ae852'),
#  ObjectId('569dc100c8ac4e03274ae853'),
#  ObjectId('569dc100c8ac4e03274ae854'),
#  ObjectId('569dc100c8ac4e03274ae855'),
#  ObjectId('569dc100c8ac4e03274ae856'),
#  ObjectId('569dc100c8ac4e03274ae857'),
#  ObjectId('569dc100c8ac4e03274ae858'),
#  ObjectId('569dc100c8ac4e03274ae859'),
#  ObjectId('569dc100c8ac4e03274ae85a'),
#  ObjectId('569dc100c8ac4e03274ae85b'),
#  ObjectId('569dc100c8ac4e03274ae85c'),
#  ObjectId('569dc100c8ac4e03274ae85d'),
#  ObjectId('569dc100c8ac4e03274ae85e'),
#  ObjectId('569dc100c8ac4e03274ae85f'),
#  ObjectId('569dc100c8ac4e03274ae860'),
#  ObjectId('569dc100c8ac4e03274ae861'),
#  ObjectId('569dc100c8ac4e03274ae862'),
#  ObjectId('569dc100c8ac4e03274ae863'),
#  ObjectId('569dc100c8ac4e03274ae864'),
#  ObjectId('569dc100c8ac4e03274ae865'),
#  ObjectId('569dc100c8ac4e03274ae866'),
#  ObjectId('569dc100c8ac4e03274ae867'),
#  ObjectId('569dc100c8ac4e03274ae868'),
#  ObjectId('569dc100c8ac4e03274ae869'),
#  ObjectId('569dc100c8ac4e03274ae86a'),
#  ObjectId('569dc100c8ac4e03274ae86b'),
#  ObjectId('569dc100c8ac4e03274ae86c'),
#  ObjectId('569dc100c8ac4e03274ae86d'),
#  ObjectId('569dc100c8ac4e03274ae86e'),
#  ObjectId('569dc100c8ac4e03274ae86f'),
#  ObjectId('569dc100c8ac4e03274ae870'),
#  ObjectId('569dc100c8ac4e03274ae871'),
#  ObjectId('569dc100c8ac4e03274ae872'),
#  ObjectId('569dc100c8ac4e03274ae873'),
#  ObjectId('569dc100c8ac4e03274ae874'),
#  ObjectId('569dc100c8ac4e03274ae875'),
#  ObjectId('569dc100c8ac4e03274ae876'),
#  ObjectId('569dc100c8ac4e03274ae877'),
#  ObjectId('569dc100c8ac4e03274ae878'),
#  ObjectId('569dc100c8ac4e03274ae879'),
#  ObjectId('569dc100c8ac4e03274ae87a'),
#  ObjectId('569dc100c8ac4e03274ae87b'),
#  ObjectId('569dc100c8ac4e03274ae87c'),
#  ObjectId('569dc100c8ac4e03274ae87d'),
#  ObjectId('569dc100c8ac4e03274ae87e'),
#  ObjectId('569dc100c8ac4e03274ae87f'),
#  ObjectId('569dc100c8ac4e03274ae880'),
#  ObjectId('569dc100c8ac4e03274ae881'),
#  ObjectId('569dc100c8ac4e03274ae882'),
#  ObjectId('569dc100c8ac4e03274ae883'),
#  ObjectId('569dc100c8ac4e03274ae884'),
#  ObjectId('569dc100c8ac4e03274ae885'),
#  ObjectId('569dc100c8ac4e03274ae886'),
#  ObjectId('569dc100c8ac4e03274ae887'),
#  ObjectId('569dc100c8ac4e03274ae888'),
#  ObjectId('569dc100c8ac4e03274ae889'),
#  ObjectId('569dc100c8ac4e03274ae88a'),
#  ObjectId('569dc100c8ac4e03274ae88b'),
#  ObjectId('569dc100c8ac4e03274ae88c'),
#  ObjectId('569dc100c8ac4e03274ae88d'),
#  ObjectId('569dc100c8ac4e03274ae88e'),
#  ObjectId('569dc100c8ac4e03274ae88f'),
#  ObjectId('569dc100c8ac4e03274ae890'),
#  ObjectId('569dc100c8ac4e03274ae891'),
#  ObjectId('569dc100c8ac4e03274ae892'),
#  ObjectId('569dc100c8ac4e03274ae893'),
#  ObjectId('569dc100c8ac4e03274ae894'),
#  ObjectId('569dc100c8ac4e03274ae895'),
#  ObjectId('569dc100c8ac4e03274ae896'),
#  ObjectId('569dc100c8ac4e03274ae897'),
#  ObjectId('569dc100c8ac4e03274ae898'),
#  ObjectId('569dc100c8ac4e03274ae899'),
#  ObjectId('569dc100c8ac4e03274ae89a'),
#  ObjectId('569dc100c8ac4e03274ae89b'),
#  ObjectId('569dc100c8ac4e03274ae89c'),
#  ObjectId('569dc100c8ac4e03274ae89d'),
#  ObjectId('569dc100c8ac4e03274ae89e'),
#  ObjectId('569dc100c8ac4e03274ae89f'),
#  ObjectId('569dc100c8ac4e03274ae8a0'),
#  ObjectId('569dc100c8ac4e03274ae8a1'),
#  ObjectId('569dc100c8ac4e03274ae8a2'),
#  ObjectId('569dc100c8ac4e03274ae8a3'),
#  ObjectId('569dc100c8ac4e03274ae8a4'),
#  ObjectId('569dc100c8ac4e03274ae8a5'),
#  ObjectId('569dc100c8ac4e03274ae8a6'),
#  ObjectId('569dc100c8ac4e03274ae8a7'),
#  ObjectId('569dc100c8ac4e03274ae8a8'),
#  ObjectId('569dc100c8ac4e03274ae8a9'),
#  ObjectId('569dc100c8ac4e03274ae8aa'),
#  ObjectId('569dc100c8ac4e03274ae8ab'),
#  ObjectId('569dc100c8ac4e03274ae8ac'),
#  ObjectId('569dc100c8ac4e03274ae8ad'),
#  ObjectId('569dc100c8ac4e03274ae8ae'),
#  ObjectId('569dc100c8ac4e03274ae8af'),
#  ObjectId('569dc100c8ac4e03274ae8b0'),
#  ObjectId('569dc100c8ac4e03274ae8b1'),
#  ObjectId('569dc100c8ac4e03274ae8b2'),
#  ObjectId('569dc100c8ac4e03274ae8b3'),
#  ObjectId('569dc100c8ac4e03274ae8b4'),
#  ObjectId('569dc100c8ac4e03274ae8b5'),
#  ObjectId('569dc100c8ac4e03274ae8b6'),
#  ObjectId('569dc100c8ac4e03274ae8b7'),
#  ObjectId('569dc100c8ac4e03274ae8b8'),
#  ObjectId('569dc100c8ac4e03274ae8b9'),
#  ObjectId('569dc100c8ac4e03274ae8ba'),
#  ObjectId('569dc100c8ac4e03274ae8bb'),
#  ObjectId('569dc100c8ac4e03274ae8bc'),
#  ObjectId('569dc100c8ac4e03274ae8bd'),
#  ObjectId('569dc100c8ac4e03274ae8be'),
#  ObjectId('569dc100c8ac4e03274ae8bf'),
#  ObjectId('569dc100c8ac4e03274ae8c0'),
#  ObjectId('569dc100c8ac4e03274ae8c1'),
#  ObjectId('569dc100c8ac4e03274ae8c2'),
#  ObjectId('569dc100c8ac4e03274ae8c3'),
#  ObjectId('569dc100c8ac4e03274ae8c4'),
#  ObjectId('569dc100c8ac4e03274ae8c5'),
#  ObjectId('569dc100c8ac4e03274ae8c6'),
#  ObjectId('569dc100c8ac4e03274ae8c7'),
#  ObjectId('569dc100c8ac4e03274ae8c8'),
#  ObjectId('569dc100c8ac4e03274ae8c9'),
#  ObjectId('569dc100c8ac4e03274ae8ca'),
#  ObjectId('569dc100c8ac4e03274ae8cb'),
#  ObjectId('569dc100c8ac4e03274ae8cc'),
#  ObjectId('569dc100c8ac4e03274ae8cd'),
#  ObjectId('569dc100c8ac4e03274ae8ce'),
#  ObjectId('569dc100c8ac4e03274ae8cf'),
#  ObjectId('569dc100c8ac4e03274ae8d0'),
#  ObjectId('569dc100c8ac4e03274ae8d1'),
#  ObjectId('569dc100c8ac4e03274ae8d2'),
#  ObjectId('569dc100c8ac4e03274ae8d3'),
#  ObjectId('569dc100c8ac4e03274ae8d4'),
#  ObjectId('569dc100c8ac4e03274ae8d5'),
#  ObjectId('569dc100c8ac4e03274ae8d6'),
#  ObjectId('569dc100c8ac4e03274ae8d7'),
#  ObjectId('569dc100c8ac4e03274ae8d8'),
#  ObjectId('569dc100c8ac4e03274ae8d9'),
#  ObjectId('569dc100c8ac4e03274ae8da'),
#  ObjectId('569dc100c8ac4e03274ae8db'),
#  ObjectId('569dc100c8ac4e03274ae8dc'),
#  ObjectId('569dc100c8ac4e03274ae8dd'),
#  ObjectId('569dc100c8ac4e03274ae8de'),
#  ObjectId('569dc100c8ac4e03274ae8df'),
#  ObjectId('569dc100c8ac4e03274ae8e0'),
#  ObjectId('569dc100c8ac4e03274ae8e1'),
#  ObjectId('569dc100c8ac4e03274ae8e2'),
#  ObjectId('569dc100c8ac4e03274ae8e3'),
#  ObjectId('569dc100c8ac4e03274ae8e4'),
#  ObjectId('569dc100c8ac4e03274ae8e5'),
#  ObjectId('569dc100c8ac4e03274ae8e6'),
#  ObjectId('569dc100c8ac4e03274ae8e7'),
#  ObjectId('569dc100c8ac4e03274ae8e8'),
#  ObjectId('569dc100c8ac4e03274ae8e9'),
#  ObjectId('569dc100c8ac4e03274ae8ea'),
#  ObjectId('569dc100c8ac4e03274ae8eb'),
#  ObjectId('569dc100c8ac4e03274ae8ec'),
#  ObjectId('569dc100c8ac4e03274ae8ed'),
#  ObjectId('569dc100c8ac4e03274ae8ee'),
#  ObjectId('569dc100c8ac4e03274ae8ef'),
#  ObjectId('569dc100c8ac4e03274ae8f0'),
#  ObjectId('569dc100c8ac4e03274ae8f1'),
#  ObjectId('569dc100c8ac4e03274ae8f2'),
#  ObjectId('569dc100c8ac4e03274ae8f3'),
#  ObjectId('569dc100c8ac4e03274ae8f4'),
#  ObjectId('569dc100c8ac4e03274ae8f5'),
#  ObjectId('569dc100c8ac4e03274ae8f6'),
#  ObjectId('569dc100c8ac4e03274ae8f7'),
#  ObjectId('569dc100c8ac4e03274ae8f8'),
#  ObjectId('569dc100c8ac4e03274ae8f9'),
#  ObjectId('569dc100c8ac4e03274ae8fa'),
#  ObjectId('569dc100c8ac4e03274ae8fb'),
#  ObjectId('569dc100c8ac4e03274ae8fc'),
#  ObjectId('569dc100c8ac4e03274ae8fd'),
#  ObjectId('569dc100c8ac4e03274ae8fe'),
#  ObjectId('569dc100c8ac4e03274ae8ff'),
#  ObjectId('569dc100c8ac4e03274ae900'),
#  ObjectId('569dc100c8ac4e03274ae901'),
#  ObjectId('569dc100c8ac4e03274ae902'),
#  ObjectId('569dc100c8ac4e03274ae903'),
#  ObjectId('569dc100c8ac4e03274ae904'),
#  ObjectId('569dc100c8ac4e03274ae905'),
#  ObjectId('569dc100c8ac4e03274ae906'),
#  ObjectId('569dc100c8ac4e03274ae907'),
#  ObjectId('569dc100c8ac4e03274ae908'),
#  ObjectId('569dc100c8ac4e03274ae909'),
#  ObjectId('569dc100c8ac4e03274ae90a'),
#  ObjectId('569dc100c8ac4e03274ae90b'),
#  ObjectId('569dc100c8ac4e03274ae90c'),
#  ObjectId('569dc100c8ac4e03274ae90d'),
#  ObjectId('569dc100c8ac4e03274ae90e'),
#  ObjectId('569dc100c8ac4e03274ae90f'),
#  ObjectId('569dc100c8ac4e03274ae910'),
#  ObjectId('569dc100c8ac4e03274ae911'),
#  ObjectId('569dc100c8ac4e03274ae912'),
#  ObjectId('569dc100c8ac4e03274ae913'),
#  ObjectId('569dc100c8ac4e03274ae914'),
#  ObjectId('569dc100c8ac4e03274ae915'),
#  ObjectId('569dc100c8ac4e03274ae916'),
#  ObjectId('569dc100c8ac4e03274ae917'),
#  ObjectId('569dc100c8ac4e03274ae918'),
#  ObjectId('569dc100c8ac4e03274ae919'),
#  ObjectId('569dc100c8ac4e03274ae91a'),
#  ObjectId('569dc100c8ac4e03274ae91b'),
#  ObjectId('569dc100c8ac4e03274ae91c'),
#  ObjectId('569dc100c8ac4e03274ae91d'),
#  ObjectId('569dc100c8ac4e03274ae91e'),
#  ObjectId('569dc100c8ac4e03274ae91f'),
#  ObjectId('569dc100c8ac4e03274ae920'),
#  ObjectId('569dc100c8ac4e03274ae921'),
#  ObjectId('569dc100c8ac4e03274ae922'),
#  ObjectId('569dc100c8ac4e03274ae923'),
#  ObjectId('569dc100c8ac4e03274ae924'),
#  ObjectId('569dc100c8ac4e03274ae925'),
#  ObjectId('569dc100c8ac4e03274ae926'),
#  ObjectId('569dc100c8ac4e03274ae927'),
#  ObjectId('569dc100c8ac4e03274ae928'),
#  ObjectId('569dc100c8ac4e03274ae929'),
#  ObjectId('569dc100c8ac4e03274ae92a'),
#  ObjectId('569dc100c8ac4e03274ae92b'),
#  ObjectId('569dc100c8ac4e03274ae92c'),
#  ObjectId('569dc100c8ac4e03274ae92d'),
#  ObjectId('569dc100c8ac4e03274ae92e'),
#  ObjectId('569dc100c8ac4e03274ae92f'),
#  ObjectId('569dc100c8ac4e03274ae930'),
#  ObjectId('569dc100c8ac4e03274ae931'),
#  ObjectId('569dc100c8ac4e03274ae932'),
#  ObjectId('569dc100c8ac4e03274ae933'),
#  ObjectId('569dc100c8ac4e03274ae934'),
#  ObjectId('569dc100c8ac4e03274ae935'),
#  ObjectId('569dc100c8ac4e03274ae936'),
#  ObjectId('569dc100c8ac4e03274ae937'),
#  ObjectId('569dc100c8ac4e03274ae938'),
#  ObjectId('569dc100c8ac4e03274ae939'),
#  ObjectId('569dc100c8ac4e03274ae93a'),
#  ObjectId('569dc100c8ac4e03274ae93b'),
#  ObjectId('569dc100c8ac4e03274ae93c'),
#  ObjectId('569dc100c8ac4e03274ae93d'),
#  ObjectId('569dc100c8ac4e03274ae93e'),
#  ObjectId('569dc100c8ac4e03274ae93f'),
#  ObjectId('569dc100c8ac4e03274ae940'),
#  ObjectId('569dc100c8ac4e03274ae941'),
#  ObjectId('569dc100c8ac4e03274ae942'),
#  ObjectId('569dc100c8ac4e03274ae943'),
#  ObjectId('569dc100c8ac4e03274ae944'),
#  ObjectId('569dc100c8ac4e03274ae945'),
#  ObjectId('569dc100c8ac4e03274ae946'),
#  ObjectId('569dc100c8ac4e03274ae947'),
#  ObjectId('569dc100c8ac4e03274ae948'),
#  ObjectId('569dc100c8ac4e03274ae949'),
#  ObjectId('569dc100c8ac4e03274ae94a'),
#  ObjectId('569dc100c8ac4e03274ae94b'),
#  ObjectId('569dc100c8ac4e03274ae94c'),
#  ObjectId('569dc100c8ac4e03274ae94d'),
#  ObjectId('569dc100c8ac4e03274ae94e'),
#  ObjectId('569dc100c8ac4e03274ae94f'),
#  ObjectId('569dc100c8ac4e03274ae950'),
#  ObjectId('569dc100c8ac4e03274ae951'),
#  ObjectId('569dc100c8ac4e03274ae952'),
#  ObjectId('569dc100c8ac4e03274ae953'),
#  ObjectId('569dc100c8ac4e03274ae954'),
#  ObjectId('569dc100c8ac4e03274ae955'),
#  ObjectId('569dc100c8ac4e03274ae956'),
#  ObjectId('569dc100c8ac4e03274ae957'),
#  ObjectId('569dc100c8ac4e03274ae958'),
#  ObjectId('569dc100c8ac4e03274ae959'),
#  ObjectId('569dc100c8ac4e03274ae95a'),
#  ObjectId('569dc100c8ac4e03274ae95b'),
#  ObjectId('569dc100c8ac4e03274ae95c'),
#  ObjectId('569dc100c8ac4e03274ae95d'),
#  ObjectId('569dc100c8ac4e03274ae95e'),
#  ObjectId('569dc100c8ac4e03274ae95f'),
#  ObjectId('569dc100c8ac4e03274ae960'),
#  ObjectId('569dc100c8ac4e03274ae961'),
#  ObjectId('569dc100c8ac4e03274ae962'),
#  ObjectId('569dc100c8ac4e03274ae963'),
#  ObjectId('569dc100c8ac4e03274ae964'),
#  ObjectId('569dc100c8ac4e03274ae965'),
#  ObjectId('569dc100c8ac4e03274ae966'),
#  ObjectId('569dc100c8ac4e03274ae967'),
#  ObjectId('569dc100c8ac4e03274ae968'),
#  ObjectId('569dc100c8ac4e03274ae969'),
#  ObjectId('569dc100c8ac4e03274ae96a'),
#  ObjectId('569dc100c8ac4e03274ae96b'),
#  ObjectId('569dc100c8ac4e03274ae96c'),
#  ObjectId('569dc100c8ac4e03274ae96d'),
#  ObjectId('569dc100c8ac4e03274ae96e'),
#  ObjectId('569dc100c8ac4e03274ae96f'),
#  ObjectId('569dc100c8ac4e03274ae970'),
#  ObjectId('569dc100c8ac4e03274ae971'),
#  ObjectId('569dc100c8ac4e03274ae972'),
#  ObjectId('569dc100c8ac4e03274ae973'),
#  ObjectId('569dc100c8ac4e03274ae974'),
#  ObjectId('569dc100c8ac4e03274ae975'),
#  ObjectId('569dc100c8ac4e03274ae976'),
#  ObjectId('569dc100c8ac4e03274ae977'),
#  ObjectId('569dc100c8ac4e03274ae978'),
#  ObjectId('569dc100c8ac4e03274ae979'),
#  ObjectId('569dc100c8ac4e03274ae97a'),
#  ObjectId('569dc100c8ac4e03274ae97b'),
#  ObjectId('569dc100c8ac4e03274ae97c'),
#  ObjectId('569dc100c8ac4e03274ae97d'),
#  ObjectId('569dc100c8ac4e03274ae97e'),
#  ObjectId('569dc100c8ac4e03274ae97f'),
#  ObjectId('569dc100c8ac4e03274ae980'),
#  ObjectId('569dc100c8ac4e03274ae981'),
#  ObjectId('569dc100c8ac4e03274ae982'),
#  ObjectId('569dc100c8ac4e03274ae983'),
#  ObjectId('569dc100c8ac4e03274ae984'),
#  ObjectId('569dc100c8ac4e03274ae985'),
#  ObjectId('569dc100c8ac4e03274ae986'),
#  ObjectId('569dc100c8ac4e03274ae987'),
#  ObjectId('569dc100c8ac4e03274ae988'),
#  ObjectId('569dc100c8ac4e03274ae989'),
#  ObjectId('569dc100c8ac4e03274ae98a'),
#  ObjectId('569dc100c8ac4e03274ae98b'),
#  ObjectId('569dc100c8ac4e03274ae98c'),
#  ObjectId('569dc100c8ac4e03274ae98d'),
#  ObjectId('569dc100c8ac4e03274ae98e'),
#  ObjectId('569dc100c8ac4e03274ae98f'),
#  ObjectId('569dc100c8ac4e03274ae990'),
#  ObjectId('569dc100c8ac4e03274ae991'),
#  ObjectId('569dc100c8ac4e03274ae992'),
#  ObjectId('569dc100c8ac4e03274ae993'),
#  ObjectId('569dc100c8ac4e03274ae994'),
#  ObjectId('569dc100c8ac4e03274ae995'),
#  ObjectId('569dc100c8ac4e03274ae996'),
#  ObjectId('569dc100c8ac4e03274ae997'),
#  ObjectId('569dc100c8ac4e03274ae998'),
#  ObjectId('569dc100c8ac4e03274ae999'),
#  ObjectId('569dc100c8ac4e03274ae99a'),
#  ObjectId('569dc100c8ac4e03274ae99b'),
#  ObjectId('569dc100c8ac4e03274ae99c'),
#  ObjectId('569dc100c8ac4e03274ae99d'),
#  ObjectId('569dc100c8ac4e03274ae99e'),
#  ObjectId('569dc100c8ac4e03274ae99f'),
#  ObjectId('569dc100c8ac4e03274ae9a0'),
#  ObjectId('569dc100c8ac4e03274ae9a1'),
#  ObjectId('569dc100c8ac4e03274ae9a2'),
#  ObjectId('569dc100c8ac4e03274ae9a3'),
#  ObjectId('569dc100c8ac4e03274ae9a4'),
#  ObjectId('569dc100c8ac4e03274ae9a5'),
#  ObjectId('569dc100c8ac4e03274ae9a6'),
#  ObjectId('569dc100c8ac4e03274ae9a7'),
#  ObjectId('569dc100c8ac4e03274ae9a8'),
#  ObjectId('569dc100c8ac4e03274ae9a9'),
#  ObjectId('569dc100c8ac4e03274ae9aa'),
#  ObjectId('569dc100c8ac4e03274ae9ab'),
#  ObjectId('569dc100c8ac4e03274ae9ac'),
#  ObjectId('569dc100c8ac4e03274ae9ad'),
#  ObjectId('569dc100c8ac4e03274ae9ae'),
#  ObjectId('569dc100c8ac4e03274ae9af'),
#  ObjectId('569dc100c8ac4e03274ae9b0'),
#  ObjectId('569dc100c8ac4e03274ae9b1'),
#  ObjectId('569dc100c8ac4e03274ae9b2'),
#  ObjectId('569dc100c8ac4e03274ae9b3'),
#  ObjectId('569dc100c8ac4e03274ae9b4'),
#  ObjectId('569dc100c8ac4e03274ae9b5'),
#  ObjectId('569dc100c8ac4e03274ae9b6'),
#  ObjectId('569dc100c8ac4e03274ae9b7'),
#  ObjectId('569dc100c8ac4e03274ae9b8'),
#  ObjectId('569dc100c8ac4e03274ae9b9'),
#  ObjectId('569dc100c8ac4e03274ae9ba'),
#  ObjectId('569dc100c8ac4e03274ae9f2'),
#  ObjectId('569dc100c8ac4e03274ae9f3'),
#  ObjectId('569dc100c8ac4e03274ae9f4'),
#  ObjectId('569dc100c8ac4e03274ae9f5'),
#  ObjectId('569dc100c8ac4e03274ae9f6'),
#  ObjectId('569dc100c8ac4e03274ae9f7'),
#  ObjectId('569dc100c8ac4e03274ae9f8'),
#  ObjectId('569dc100c8ac4e03274ae9f9'),
#  ObjectId('569dc100c8ac4e03274ae9fa'),
#  ObjectId('569dc100c8ac4e03274ae9fb'),
#  ObjectId('569dc100c8ac4e03274ae9fc'),
#  ObjectId('569dc100c8ac4e03274ae9fd'),
#  ObjectId('569dc100c8ac4e03274ae9fe'),
#  ObjectId('569dc100c8ac4e03274ae9ff'),
#  ObjectId('569dc100c8ac4e03274aea00'),
#  ObjectId('569dc100c8ac4e03274aea01'),
#  ObjectId('569dc100c8ac4e03274aea02'),
#  ObjectId('569dc100c8ac4e03274aea03'),
#  ObjectId('569dc100c8ac4e03274aea04'),
#  ObjectId('569dc100c8ac4e03274aea05'),
#  ObjectId('569dc100c8ac4e03274aea06'),
#  ObjectId('569dc100c8ac4e03274aea07'),
#  ObjectId('569dc100c8ac4e03274aea08'),
#  ObjectId('569dc100c8ac4e03274aea09'),
#  ObjectId('569dc100c8ac4e03274aea0a'),
#  ObjectId('569dc100c8ac4e03274aea0b'),
#  ObjectId('569dc100c8ac4e03274aea0c'),
#  ObjectId('569dc100c8ac4e03274aea0d'),
#  ObjectId('569dc100c8ac4e03274aea0e'),
#  ObjectId('569dc100c8ac4e03274aea0f'),
#  ObjectId('569dc100c8ac4e03274aea10'),
#  ObjectId('569dc100c8ac4e03274aea11'),
#  ObjectId('569dc100c8ac4e03274aea12'),
#  ObjectId('569dc100c8ac4e03274aea13'),
#  ObjectId('569dc100c8ac4e03274aea14'),
#  ObjectId('569dc100c8ac4e03274aea15'),
#  ObjectId('569dc100c8ac4e03274aea16'),
#  ObjectId('569dc100c8ac4e03274aea17'),
#  ObjectId('569dc100c8ac4e03274aea18'),
#  ObjectId('569dc100c8ac4e03274aea19'),
#  ObjectId('569dc100c8ac4e03274aea1a'),
#  ObjectId('569dc100c8ac4e03274aea1b'),
#  ObjectId('569dc100c8ac4e03274aea1c'),
#  ObjectId('569dc100c8ac4e03274aea1d'),
#  ObjectId('569dc100c8ac4e03274aea1e'),
#  ObjectId('569dc100c8ac4e03274aea1f'),
#  ObjectId('569dc100c8ac4e03274aea20'),
#  ObjectId('569dc100c8ac4e03274aea21'),
#  ObjectId('569dc100c8ac4e03274aea22'),
#  ObjectId('569dc100c8ac4e03274aea23'),
#  ObjectId('569dc100c8ac4e03274aea24'),
#  ObjectId('569dc100c8ac4e03274aea25'),
#  ObjectId('569dc100c8ac4e03274aea26'),
#  ObjectId('569dc100c8ac4e03274aea27'),
#  ObjectId('569dc100c8ac4e03274aea28'),
#  ObjectId('569dc100c8ac4e03274aea29'),
#  ObjectId('569dc100c8ac4e03274aea2a'),
#  ObjectId('569dc100c8ac4e03274aea2b'),
#  ObjectId('569dc100c8ac4e03274aea2c'),
#  ObjectId('569dc100c8ac4e03274aea2d'),
#  ObjectId('569dc100c8ac4e03274aea2e'),
#  ObjectId('569dc100c8ac4e03274aea2f'),
#  ObjectId('569dc100c8ac4e03274aea30'),
#  ObjectId('569dc100c8ac4e03274aea31'),
#  ObjectId('569dc100c8ac4e03274aea32'),
#  ObjectId('569dc100c8ac4e03274aea33'),
#  ObjectId('569dc100c8ac4e03274aea34'),
#  ObjectId('569dc100c8ac4e03274aea35'),
#  ObjectId('569dc100c8ac4e03274aea36'),
#  ObjectId('569dc100c8ac4e03274aea37'),
#  ObjectId('569dc100c8ac4e03274aea38'),
#  ObjectId('569dc100c8ac4e03274aea39'),
#  ObjectId('569dc100c8ac4e03274aea3a'),
#  ObjectId('569dc100c8ac4e03274aea3b'),
#  ObjectId('569dc100c8ac4e03274aea3c'),
#  ObjectId('569dc100c8ac4e03274aea3d'),
#  ObjectId('569dc100c8ac4e03274aea3e'),
#  ObjectId('569dc100c8ac4e03274aea3f'),
#  ObjectId('569dc100c8ac4e03274aea40'),
#  ObjectId('569dc100c8ac4e03274aea41'),
#  ObjectId('569dc100c8ac4e03274aea42'),
#  ObjectId('569dc100c8ac4e03274aea43'),
#  ObjectId('569dc100c8ac4e03274aea44'),
#  ObjectId('569dc100c8ac4e03274aea45'),
#  ...]

# %%
#testing it out
print db.atx.find_one()
# Out:
# {u'created': {u'changeset': u'8497118', u'user': u'Tylan', u'version': u'15', u'uid': u'388279', u'timestamp': u'2011-06-20T18:36:15Z'}, u'_id': ObjectId('569dc100c8ac4e03274ae65e'), u'type': u'node', u'id': u'26546004', u'pos': [30.4695355, -97.7972587]}

# %%
print db.atx.find().count()  #number of docs
print db.atx.find({"type":"node"}).count()  #number of nodes
print db.atx.find({"type":"way"}).count()   #number of ways
print len(db.atx.distinct("created.user"))  #number of distinct users
# Out:
# 1031

# %%
def make_pipeline():
    #these are all the different pipelines for aggregation included in the report
    
    
    
    #pipeline = [{"$group":{"_id":"$created.user", 
    #                       "count":{"$sum":1}}}, 
    #            { "$sort":{"count": ‐1}},
    #            {"$limit":1}]
    
    #pipeline = [{"$group":{"_id":"$created.user", 
    #                       "count":{"$sum":1}}},  
    #            {"$group":{"_id":"$count", 
    #                       "num_users":{"$sum":1}}},  
    #            {"$sort":{"_id":1}},
    #            {"$limit":1}]
    
    #pipeline = [{"$match":{"amenity":{"$exists":1}}}, 
    #            {"$group":{"_id":"$amenity",
    #                       "count":{"$sum":1}}}, 
    #            {"$sort":{"count": ‐1}},
    #            {"$limit":10}]
    
    #pipeline = [{"$match":{"amenity":{"$exists":1}, 
    #                       "amenity":"place_of_worship"}},
    #            {"$group":{"_id":"$religion", 
    #                       "count":{"$sum":1}}},
    #            {"$sort":{"count": ‐1}},
    #            {"$limit":1}]
    
    #pipeline = [{"$match":{"amenity":{"$exists":1}, 
    #                       "amenity":"restaurant"}},  
    #            {"$group":{"_id":"$cuisine", 
    #                       "count":{"$sum":1}}},
    #            {"$sort":{"count": ‐1}},
    #            {"$limit":3}]
    
    pipeline = [{"$group" : {"_id":"$created.user",
                            "count":{"$sum":1}}},
                {"$sort":{"count":1}},
                {"$limit":100}]
    
    return pipeline

if __name__ == '__main__':
    pipeline = make_pipeline()
    result = [doc for doc in db.atx.aggregate(pipeline)]
    import pprint
    if len(result) < 150:
        pprint.pprint(result)
    else:
        pprint.pprint(result[:100])
# Out:
# [{u'_id': u'justcaldwell', u'count': 1},
#  {u'_id': u'jarcher', u'count': 1},
#  {u'_id': u'mrw6060', u'count': 1},
#  {u'_id': u'Jeff Yutzler', u'count': 1},
#  {u'_id': u'Red Stella', u'count': 1},
#  {u'_id': u'coinfaq', u'count': 1},
#  {u'_id': u'RobCo', u'count': 1},
#  {u'_id': u'Hartmut Holzgraefe', u'count': 1},
#  {u'_id': u'OpenBrian', u'count': 1},
#  {u'_id': u'geojwh', u'count': 1},
#  {u'_id': u'mhm44', u'count': 1},
#  {u'_id': u'taranis83', u'count': 1},
#  {u'_id': u'adi_z', u'count': 1},
#  {u'_id': u'wieland', u'count': 1},
#  {u'_id': u'jacmin', u'count': 1},
#  {u'_id': u'marook', u'count': 1},
#  {u'_id': u'ahmef', u'count': 1},
#  {u'_id': u'Pete Trujillo', u'count': 1},
#  {u'_id': u'mp2526', u'count': 1},
#  {u'_id': u'Robert Butler', u'count': 1},
#  {u'_id': u'wolfie78', u'count': 1},
#  {u'_id': u'Davio', u'count': 1},
#  {u'_id': u'BryanSK', u'count': 1},
#  {u'_id': u'manishchacko', u'count': 1},
#  {u'_id': u'joshparnham', u'count': 1},
#  {u'_id': u'livingeasy', u'count': 1},
#  {u'_id': u'Chris Baines', u'count': 1},
#  {u'_id': u'SHed', u'count': 1},
#  {u'_id': u'Mike Aiello', u'count': 1},
#  {u'_id': u'John Hammond', u'count': 1},
#  {u'_id': u'luismartinex', u'count': 1},
#  {u'_id': u'Japa', u'count': 1},
#  {u'_id': u'ahooks', u'count': 1},
#  {u'_id': u'alester', u'count': 1},
#  {u'_id': u'Katie greeley', u'count': 1},
#  {u'_id': u'JABURNS', u'count': 1},
#  {u'_id': u'DrBekanich', u'count': 1},
#  {u'_id': u'Vosco Moving Austin', u'count': 1},
#  {u'_id': u'clairehhlin', u'count': 1},
#  {u'_id': u'Jeremy Powell', u'count': 1},
#  {u'_id': u'GeoffTurner', u'count': 1},
#  {u'_id': u'rbeede', u'count': 1},
#  {u'_id': u'ccrockett', u'count': 1},
#  {u'_id': u'Bryan Bartow', u'count': 1},
#  {u'_id': u'florinbadita_telenav', u'count': 1},
#  {u'_id': u'savehv', u'count': 1},
#  {u'_id': u'Stephen Oh', u'count': 1},
#  {u'_id': u'BitcoinMaps', u'count': 1},
#  {u'_id': u'spongocoel', u'count': 1},
#  {u'_id': u'Karisa', u'count': 1},
#  {u'_id': u'jrouquie', u'count': 1},
#  {u'_id': u'jillianletemendia', u'count': 1},
#  {u'_id': u'ubahnverleih', u'count': 1},
#  {u'_id': u'AJ Processing', u'count': 1},
#  {u'_id': u'youngjb06', u'count': 1},
#  {u'_id': u'Satoshi Square', u'count': 1},
#  {u'_id': u'Bridger', u'count': 1},
#  {u'_id': u'axcel80', u'count': 1},
#  {u'_id': u'tallices', u'count': 1},
#  {u'_id': u'mziehm', u'count': 1},
#  {u'_id': u'lumpinator', u'count': 1},
#  {u'_id': u'cart0', u'count': 1},
#  {u'_id': u'egootee', u'count': 1},
#  {u'_id': u'DeanHend1', u'count': 1},
#  {u'_id': u'StevenP', u'count': 1},
#  {u'_id': u'mueschel', u'count': 1},
#  {u'_id': u'TomHynes', u'count': 1},
#  {u'_id': u'TOGA', u'count': 1},
#  {u'_id': u'Gregory Cashen', u'count': 1},
#  {u'_id': u'dwyang95', u'count': 1},
#  {u'_id': u'Rockear', u'count': 1},
#  {u'_id': u'shri3k', u'count': 1},
#  {u'_id': u'Zen Windows of Austin', u'count': 1},
#  {u'_id': u'StephaneP', u'count': 1},
#  {u'_id': u'jincopunk', u'count': 1},
#  {u'_id': u'troypdx', u'count': 1},
#  {u'_id': u'ragecage', u'count': 1},
#  {u'_id': u'iONiX', u'count': 1},
#  {u'_id': u'nickel715', u'count': 1},
#  {u'_id': u'Austin Alex', u'count': 1},
#  {u'_id': u'kourt', u'count': 1},
#  {u'_id': u'bjtexas', u'count': 1},
#  {u'_id': u'Cat2102', u'count': 1},
#  {u'_id': u'wiedergaenger', u'count': 1},
#  {u'_id': u'Jacob Miller', u'count': 1},
#  {u'_id': u'texaskdog', u'count': 1},
#  {u'_id': u'dcs', u'count': 1},
#  {u'_id': u'MrCippy', u'count': 1},
#  {u'_id': u'Jake Strine', u'count': 1},
#  {u'_id': u'lesko987', u'count': 1},
#  {u'_id': u'SomeoneElse', u'count': 1},
#  {u'_id': u'mheffler', u'count': 1},
#  {u'_id': u'ams501', u'count': 1},
#  {u'_id': u'kt3313', u'count': 1},
#  {u'_id': u'Jmntx', u'count': 1},
#  {u'_id': u'chinaski93', u'count': 1},
#  {u'_id': u'Orangey', u'count': 1},
#  {u'_id': u'David Paleino', u'count': 1},
#  {u'_id': u'Echsecutor', u'count': 1},
#  {u'_id': u'pawelh', u'count': 1}]

# %%
#some math for stats included on the file
2747363+1302500+941550+354652+301759+159464+157899+48236
# Out:
# 6013423

# %%
6013423/6319385.0
# Out:
# 0.9515835797312555

# %%
100/6319385.0
# Out:
# 1.5824324677163996e-05

# %%
#Lesson 6 Quizzes
#6.1



#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Your task is to use the iterative parsing to process the map file and
find out not only what tags are there, but also how many, to get the
feeling on how much of which data you can expect to have in the map.
Fill out the count_tags function. It should return a dictionary with the 
tag name as the key and number of times this tag can be encountered in 
the map as value.

Note that your code will be tested with a different data file than the 'example.osm'
"""
import xml.etree.cElementTree as ET
import pprint

def count_tags(filename):
    count_dict = {}
    for event, elem in ET.iterparse(filename):
        if elem.tag in count_dict:
            count_dict[elem.tag] += 1
        else:
            count_dict[elem.tag] = 1

    return count_dict

def test():

    tags = count_tags('example.osm')
    pprint.pprint(tags)
    assert tags == {'bounds': 1,
                     'member': 3,
                     'nd': 4,
                     'node': 20,
                     'osm': 1,
                     'relation': 1,
                     'tag': 7,
                     'way': 1}

    

if __name__ == "__main__":
    test()

# %%
#6.2



#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
Before you process the data and add it into MongoDB, you should check the "k"
value for each "<tag>" and see if they can be valid keys in MongoDB, as well as
see if there are any other potential problems.

We have provided you with 3 regular expressions to check for certain patterns
in the tags. As we saw in the quiz earlier, we would like to change the data
model and expand the "addr:street" type of keys to a dictionary like this:
{"address": {"street": "Some value"}}
So, we have to see if we have such tags, and if we have any tags with
problematic characters.

Please complete the function 'key_type', such that we have a count of each of
four tag categories in a dictionary:
  "lower", for tags that contain only lowercase letters and are valid,
  "lower_colon", for otherwise valid tags with a colon in their names,
  "problemchars", for tags with problematic characters, and
  "other", for other tags that do not fall into the other three categories.
See the 'process_map' and 'test' functions for examples of the expected format.
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            if lower.match(tag.attrib['k']):
                keys['lower'] += 1
            elif lower_colon.match(tag.attrib['k']):
                keys['lower_colon'] += 1
            elif problemchars.match(tag.attrib['k']):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
        
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys



def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertion below will be incorrect then.
    # Note as well that the test function here is only used in the Test Run;
    # when you submit, your code will be checked against a different dataset.
    keys = process_map('example.osm')
    pprint.pprint(keys)
    assert keys == {'lower': 5, 'lower_colon': 0, 'other': 1, 'problemchars': 1}


if __name__ == "__main__":
    test()

# %%
#6.3



#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
The first task is a fun one - find out how many unique users
have contributed to the map in this particular area!

The function process_map should return a set of unique user IDs ("uid")
"""

def get_user(element):
    return


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for tag in element.iter('node'):
            users.add(tag.attrib['uid'])
        for tag in element.iter('way'):
            users.add(tag.attrib['uid'])
        for tag in element.iter('relation'):
            users.add(tag.attrib['uid'])
                    

    return users


def test():

    users = process_map('example.osm')
    pprint.pprint(users)
    assert len(users) == 6



if __name__ == "__main__":
    test()

# %%
#6.4



"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "example.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Rd." : "Road",
            "Rd" : "Road"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types


def update_name(name, mapping):
    #print name.split(" ")[-1]
    # YOUR CODE HERE
    split_name = name.split(" ")
    postfix = split_name[-1]
    if postfix in mapping:
        postfix = mapping[postfix]
        split_name_clean = split_name[:-1]
        split_name_clean.append(postfix)
        name = " ".join(split_name_clean)
    return name


def test():
    st_types = audit(OSMFILE)
    assert len(st_types) == 3
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            if name == "West Lexington St.":
                assert better_name == "West Lexington Street"
            if name == "Baldwin Rd.":
                assert better_name == "Baldwin Road"


if __name__ == '__main__':
    test()

# %%
#6.5



#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
"""
Your task is to wrangle the data and transform the shape of the data
into the model we mentioned earlier. The output should be a list of dictionaries
that look like this:

{
"id": "2406124091",
"type: "node",
"visible":"true",
"created": {
          "version":"2",
          "changeset":"17206049",
          "timestamp":"2013-08-03T16:43:42Z",
          "user":"linuxUser16",
          "uid":"1219059"
        },
"pos": [41.9757030, -87.6921867],
"address": {
          "housenumber": "5157",
          "postcode": "60625",
          "street": "North Lincoln Ave"
        },
"amenity": "restaurant",
"cuisine": "mexican",
"name": "La Cabana De Don Luis",
"phone": "1 (773)-271-5176"
}

You have to complete the function 'shape_element'.
We have provided a function that will parse the map file, and call the function with the element
as an argument. You should return a dictionary, containing the shaped data for that element.
We have also provided a way to save the data in a file, so that you could use
mongoimport later on to import the shaped data into MongoDB. 

Note that in this exercise we do not use the 'update street name' procedures
you worked on in the previous exercise. If you are using this code in your final
project, you are strongly encouraged to use the code from previous exercise to 
update the street names before you save them to JSON. 

In particular the following things should be done:
- you should process only 2 types of top level tags: "node" and "way"
- all attributes of "node" and "way" should be turned into regular key/value pairs, except:
    - attributes in the CREATED array should be added under a key "created"
    - attributes for latitude and longitude should be added to a "pos" array,
      for use in geospacial indexing. Make sure the values inside "pos" array are floats
      and not strings. 
- if second level tag "k" value contains problematic characters, it should be ignored
- if second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
- if second level tag "k" value does not start with "addr:", but contains ":", you can process it
  same as any other tag.
- if there is a second ":" that separates the type/direction of a street,
  the tag should be ignored, for example:

<tag k="addr:housenumber" v="5158"/>
<tag k="addr:street" v="North Lincoln Avenue"/>
<tag k="addr:street:name" v="Lincoln"/>
<tag k="addr:street:prefix" v="North"/>
<tag k="addr:street:type" v="Avenue"/>
<tag k="amenity" v="pharmacy"/>

  should be turned into:

{...
"address": {
    "housenumber": 5158,
    "street": "North Lincoln Avenue"
}
"amenity": "pharmacy",
...
}

- for "way" specifically:

  <nd ref="305896090"/>
  <nd ref="1719825889"/>

should be turned into
"node_refs": ["305896090", "1719825889"]
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    
    node = {}
    address = {}
    pos=[]
    node['pos'] = pos
    
    if element.tag == "node" or element.tag == "way" :
        node['id'] = element.attrib['id']
        node['type'] = element.tag
        if 'visible' in element.attrib:
            node['visible'] = element.attrib['visible']
       
        created = {}
        for i in CREATED:
            created[i]=element.attrib[i]  
            node['created']=created
                                              
        for elem in element:
            if 'k' in elem.attrib:
                if elem.attrib['k'].count(':')<2:
                    if elem.attrib['k'].startswith("addr:"):
                        stripped=elem.attrib['k'].replace("addr:","")
                        if stripped == 'housenumber' or stripped == 'street':
                            address[stripped] = elem.attrib['v']
                            node['address'] = address
                    else:
                        node[elem.attrib['k']]=elem.attrib['v']

        try:
            node["amenity"]=element.attrib['amenity']
        except :
            pass
        try:
            node["cuisine"]=element.attrib['cuisine']
        except :
            pass        
        try:
            node["name"]=element.attrib['name']
        except :
            pass
        try:
            node["phone"]=element.attrib['phone']
        except :
            pass 
        try:
            node['pos'].append(float(element.attrib['lat']))
            node['pos'].append(float(element.attrib['lon']))             
        except : 
            pass
                                                           
        #print node
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map('example.osm', True)
    #pprint.pprint(data)
    
    correct_first_elem = {
        "id": "261114295", 
        "visible": "true", 
        "type": "node", 
        "pos": [41.9730791, -87.6866303], 
        "created": {
            "changeset": "11129782", 
            "user": "bbmiller", 
            "version": "7", 
            "uid": "451048", 
            "timestamp": "2012-03-28T18:31:23Z"
        }
    }
    assert data[0] == correct_first_elem
    assert data[-1]["address"] == {
                                    "street": "West Lexington St.", 
                                    "housenumber": "1412"
                                      }
    assert data[-1]["node_refs"] == [ "2199822281", "2199822390",  "2199822392", "2199822369", 
                                    "2199822370", "2199822284", "2199822281"]

if __name__ == "__main__":
    test()
